# %% [markdown]
# ## Set Up Neo4j Environment

# %% [markdown]
# Start by creating Neo4jGraph instance

# %%
import os
from dotenv import load_dotenv
from langchain_community.graphs import Neo4jGraph


# Load from environment
load_dotenv('.env', override=True)
NEO4J_URI = os.getenv('NEO4J_URI')
NEO4J_USERNAME = os.getenv('NEO4J_USERNAME')
NEO4J_PASSWORD = os.getenv('NEO4J_PASSWORD')
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
#graph = Neo4jGraph(refresh_schema=False)

# %% [markdown]
# ## Chunk Text

# %% [markdown]
# In the microsoft paper, it is recommended to use smaller chunk sizes (~600) to extract more entities overall. The steps for this section are:
# - Import PDFs for this example (lets use 2 papers)
# - Convert PDF to markdown or txt files (use matextract workflow as basis)
# - Chunk text from articles (will have to explore best way to do this)

# %% [markdown]
# Covert pdf to md using marker:

# %%
! marker_single data/pdf/10.1038s41586-019-1798-7.pdf data/md --langs English
# Out:
# Loaded detection model vikp/surya_det3 on device cpu with dtype torch.float32
# Detecting bboxes:   0%|          | 0/2 [00:00<?, ?it/s]
# Loaded detection model vikp/surya_layout3 on device cpu with dtype torch.float32
# Loaded reading order model vikp/surya_order on device cpu with dtype torch.float32
# Loaded recognition model vikp/surya_rec on device cpu with dtype torch.float32
# Loaded texify model to cpu with torch.float32 dtype

# %% [markdown]
# Clean up markdown file, removing sections, etc. For this example, I'll do a more simple approach and use just one .md file. We'll take the text and save it as a single chunk.
#
# To scale this workflow, we'd use multiple chunks (from multiple papers), instead of just one. We could use a vector database to store a lot of chunks, and retrieve the most relevant ones.
#
# ChemNLP offers a more thorough workflow for cleaning up .md files generated from scholarly articles.

# %%
import re

def clean_text(text):
    # Delete the pattern [MISSING_PAGE_FAIL:x]
    cleaned_text = re.sub(r"\[MISSING_PAGE_FAIL:\d+\]", "", text)

    # Delete the acknowledgements section
    cleaned_text = re.sub(
        r"## Acknowledgements.*?(?=##|$)", "", cleaned_text, flags=re.S
    )

    # delete the references section 
    cleaned_text = re.sub(r"## *Notes And References.*", "", cleaned_text, flags=re.S)

    return cleaned_text



input_file = "data/md/10.1039c0dt00999g/10.1039c0dt00999g.md"

with open(input_file, "r", encoding="utf-8") as f:
    content = f.read()

# clean the text
text = clean_text(content)
print(text)
# Out:
# This article is published as part of the *Dalton Transactions* **themed issue entitled:**
#
# # New Talent Asia
#
# Highlighting the excellent work being carried out by younger members of the inorganic academic community in Asia Guest Editor Masahiro Yamashita Tohoku University, Japan Published in issue 10, 2011 of *Dalton Transactions*
#
# ![0_image_0.png](0_image_0.png)
#
# Image reproduced with permission of Kenneth Kam-Wing Lo Articles in the issue include: PERSPECTIVES: Pyrazolin-4-ylidenes: a new class of intriguing ligands Yuan Han and Han Vinh Huynh, *Dalton Trans*., 2011, DOI: 10.1039/C0DT01037E Solvent induced molecular magnetic changes observed in single-crystal-to-single-crystal transformation Zheng-Ming Hao and Xian-Ming Zhang, *Dalton Trans*., 2011, DOI: 10.1039/C0DT00979B, ARTICLES:
# Negative thermal expansion emerging upon structural phase transition in ZrV2O7 and HfV2O7 Yasuhisa Yamamura, Aruto Horikoshi, Syuma Yasuzuka, Hideki Saitoh and Kazuya Saito Dalton Trans., 2011, DOI: 10.1039/C0DT01087A
# Preparation of surface molecularly imprinted Ru-complex catalysts for asymmetric transfer hydrogenation in water media Zhihuan Weng, Satoshi Muratsugu, Nozomu Ishiguro, Shin-ichi Ohkoshi and Mizuki Tada Dalton Trans., 2011, DOI: 10.1039/C0DT00950D
# Visit the *Dalton Transactions* website for more cutting-edge inorganic and organometallic research www.rsc.org/dalton
#
# # Microporous Sensor: Gas Sorption, Guest Exchange And Guest-Dependant Luminescence Of Metal–Organic Framework†
#
# Sergey A. Sapchenko,a Denis G. Samsonenko,*a,b Danil N. Dybtsev,a,c Maxim S. Melgunovd and Vladimir P. Fedina,b Received 12th August 2010, Accepted 14th October 2010 DOI: 10.1039/c0dt00999g Zn(II)-containing metal–organic framework (MOF) [Zn4(dmf)(ur)2(ndc)4] (ndc2- =
# 2,6-naphtalenedicarboxylate, ur = urotropin, dmf = N,N¢-dimethylformamide) was synthesized and characterized by X-ray crystallography and gas sorption analysis. Host MOF retains its crystallinity after guest removal and exchange. Single-crystal to single-crystal formation of different host–guest systems with benzene and ferrocene was investigated. Interesting guest-depended luminescence properties of the porous host framework were observed.
#
# ## Introduction
#
# Metal–organic coordination polymers constructed from metal ions and organic bridging ligands have attracted considerable attention in recent years.1 The wide variety of organic ligands and practically infinite number of ways to unite metal coordination complexes into extended metal–organic framework lead to a vast number of novel compounds with unique sorption, catalytic activity, luminescence, magnetism.2,3 While gas sorption or catalytic activity of metal–organic frameworks mainly depends on the structure, some other properties, *e.g.* luminescence, depend also on the guest composition, which could be directly applied for chemical sensing. Therefore the synthesis of porous metal–organic frameworks, which are capable of switching their functional characteristics upon guest-related transitions, is an important but challenging task. Other than luminescence itself, such sensor materials should feature at least two essential properties. Firstly, the size of porous channels must be sufficient for accommodation of functional guest species. Secondly, the metal–organic framework should be robust enough to maintain its porosity during the guest removal or exchange. Only several examples of porous coordination polymers with luminescence-based sensing of various guest molecules have been reported to date,4 therefore this highly promising area mainly remains underdeveloped. A
# particularly important issue here is an unambiguous structural characterization of such host–guest complexes because it allows detailed investigation of interactions between guest molecule and porous framework as well as elucidates the sensing mechanism.
#
# Single-crystal X-ray diffraction technique is often limited here, because of guest disorder problem or fragility of metal-organic single crystals during the guest exchange.5 In this work we describe the synthesis and characterization of a novel porous metal–organic coordination polymer
# [Zn4(dmf)(ur)2(ndc)4]·5DMF·H2O (1), which meets the abovementioned requirements for potential sensor applications. The solvent molecules can be removed from this MOF without loss of the sample's crystallinity. The resulting permanently porous framework demonstrates a reversible gas sorption as well as an uptake of various guests. The corresponding guest-free and guest-exchanged samples were characterized by a single-crystal X-ray diffraction analysis. Most interestingly, the luminescent properties of open framework [Zn4(dmf)(ur)2(ndc)4] are highly depended on the guest molecules, accommodated in the pores. The benzene molecules enhance the framework luminescence, while ferrocene effectively quenches it. Such pronounced guestdepended response could be applied for sensing of organic or organometallic molecules, many of which are very dangerous both to Nature and to human health.
#
# ## Results And Discussion
#
# Compound 1 was obtained by heating a mixture of Zn(NO3)2·6H2O, 2,6-naphtalenedicarboxylic acid (H2ndc) and urotropin (ur) in DMF at 100 ◦C for 10 h. Compound 1 crystallizes in the monoclinic system with the space group P21/n. Asymmetric unit of 1 comprises four crystallographically independent zinc atoms forming two different binuclear carboxylate complexes as secondary building units (Fig. 1). In the first building unit (type A) the tetragonal-pyramidal Zn(1) and Zn(2) centers are similar.
#
# Each metal cation is coordinated by four O atoms of four ndc2- and one N atom of urotropin, such as these cations are interconnected via four bridging bidentate m2-RCOO-O,O¢ groups. This binuclear carboxylate complex {Zn2(COO)4}, known as "paddle-wheel",
# is very typical and common in metal carboxylate coordination structures. The Zn–O (2.006(5)–2.069(6) A˚ ) and Zn–N (2.065(6), 2.067(6) A˚ ) bond lengths found fall within the common values for Zn(II) complexes with coordination number 5. The structure of the second carboxylate secondary building unit (type B), to our best
#
# ![2_image_0.png](2_image_0.png)
#
# knowledge, has never been described before and unprecedented in coordination frameworks. Contrary to the binuclear complex A, the coordination environments of Zn(3) and Zn(4) cations in B are different (Fig. 1). The distorted tetrahedral Zn(3) center is coordinated by three O atoms of three ndc2- ligands and one N atom of urotropin. The Zn(3)–O (1,899(9)–1,962(7) A˚ ) and Zn(3)–N(12) (2.111(7) A˚ ) bond lengths found fall within the common values for tetrahedral Zn(II) complexes. The distorted octahedral geometry of Zn(4) cation is composed of five O atoms of two monodentate ndc2-, one chelating bidentate ndc2- ligands and one coordinated dmf molecule, as well as one N atom of urotropin ligand. The Zn(4)–N(22) bond length is 2.143(7) A˚ .
#
# There are two type of Zn(4)–O distances. The first one includes two bonds with bridging ndc2- ligands (1.982(7), 1.997(6) A˚ )
# and one of two bonds with bidentate ndc2- ligand (2.161(16)
# A˚ ). The residual bond with bidentate ndc2- ligand and bond with dmf molecule form the second type. Thereby, coordination number of Zn(4) atom can be assigned as 4 + 2. In the type B
# building unit two metal cations Zn(3) and Zn(4) are interlinked via two bridging m2-RCOO-O,O¢ groups, so the overall formula of the coordination complex is {Zn2(dmf)(COO)4}. The metal–
# ligand distances in both carboxylate binuclear complexes lie within typical corresponding ranges with some acceptable deviations, indicating apparent distortion.
#
# In the structure 1 the organic ligands act as ditopic connectors between the binuclear secondary building units. Therefore, both binuclear complexes A and B could be simplified as six-connected nodes, each with distorted 4 + 2 octahedral geometry of four linear ndc2- and two angular urotropin linkers. The main difference is that urotropins are located in *trans*-positions in type A but in cis-positions in the type B node (Fig. 1). The ndc2- bridges connect nodes A and A, B and B, as well as A and B. At the same time urotropin ligands link only nodes A and B. Each type A node is connected through ndc2- to two nodes A and two nodes B
# and through urotropin to two nodes B. Similarly, each B node is connected through ndc2- to two nodes A and two B and through urotropin to two nodes A. The overall three-dimensional (3D)
# topology of the binodal 6-connected net in the metal–organic framework 1 is very complicated (Fig. S1†), one may refer to its point symbol (3244.68.8)(3.44.53.66.8).
#
# The interstitial space between inorganic carboxylate complexes and organic ligands in as-synthesized 1 is occupied by solvent guest molecules. The single-crystal X-ray diffraction analysis revealed five DMF and one H2O molecules per asymmetric unit of 1. The formula [Zn4(dmf)(ur)2(ndc)4]·5DMF·H2O was independently confirmed by elemental and thermogravimetrical
# (TG) analyses. The phase purity of 1 was also proved by powder X-ray diffraction method (See SI for the details). In particular, the TG analysis on the as-synthesized 1 indicated a gradual weight loss of 21% in the temperature range 25–300 ◦C, which is consistent with evacuation of one H2O and 5 DMF molecules. The following decrease of mass can be associated with the destruction of the metal–organic framework (Fig. S2). The guest molecules occupy distorted hexagonal channels with characteristic dimensions 9.5
# ¥ 11 A˚ 2, running along a axis of 3D framework (Fig. 2). A space within channels is occupied by DMF and disordered H2O guest molecules, which form a weak H-bonding with CH or CH2 groups of ndc2- or urotropin ligands respectively, as well as with each
#
# ![3_image_1.png](3_image_1.png)
#
# To prepare guest-free framework [Zn4(dmf)(ur)2(ndc)4] (2) the DMF molecules was exchanged with readily volatile CH2Cl2 solvent, followed by slight heating in the dynamic vacuum. A structure of guest-free compound 2 is generally similar to 1, but there are some distinct differences. Whereas the compound 1 crystallizes in *P21/n* space group, compound 2 has slightly higher Cc symmetry. Such difference does not affect significantly Zn– O and Zn–N interatomic distances. The channels running along c axis in 2 adopt more symmetric shape than in 1 and have characteristic dimensions 10.5 ¥ 10.5 A˚ (Fig. 3). The free solvent accessible volume in 2, derived from PLATON 6 routine analysis
# (filling of the cavities with probe spheres of radius 1.2 A˚ ) was found to be 43%. Interestingly, framework 2 is not centrosymmetric
# (sp. group Cc has no inversion center) that leads to racemic merohedral twinning of the crystals 2 contrary to 1. Attempts to apply centrosymmetric space group C2/c during the refinement of 2 leads to disorder of coordinated dmf molecules over two symmetrically related positions. In case of non centrosymmetric group Cc, the disordering is not observed.
#
# The high stability of the guest-free metal–organic framework was further confirmed by N2 sorption isotherm at 77 K for 2
# (Fig. 4), which shows type I behavior with small hysteresis and
#
# ![3_image_0.png](3_image_0.png)
#
# ![3_image_2.png](3_image_2.png)
#
# thus ensuring permanent microporosity of the bulk sample. The formally calculated Brunauer–Emmett–Teller (BET) surface area is 820 m2 g-1. Channels volume-size distribution diagram (Fig. S3†)
# shows the only intense peak at 0.9 nm and agrees quantitatively with the result of X-ray analysis. The volume of these pores was calculated to be 0.2 cm3 g-1. The maximum H2 uptake for 2 at 1 atm and 77 K is 0.92 wt.% H2 (Fig. 5). Knowing pore volume, one can estimate the density of H2 in pores as 0.04 g cm-3. For comparison, density of liquid H2 at 14 K is 0.07 g cm-3. The storage density of hydrogen in the bulk sample at 1 bar is 0.009 g cm-3, which is equivalent to the density of H2 at 2.7 MPa (estimated according
#
# ![4_image_0.png](4_image_0.png)
#
# to ideal gas equation) at 77 K. Additional hydrogen isotherm was measured at 87 K to determine enthalpy of adsorption derived from the Clausius–Clapeyron equation (see Fig. S4 and S5 in ESI† for details). In the interval of 0.1–1.0 wt. % of adsorbed H2, value of D*Hads* lies in the range 4.7–5.2 kJ mol-1, which is typical to other zinc–organic frameworks.2a Microporous framework 2 can form different host–guest complexes with various species ranging from diatomic molecules to organometallics. Immersing single crystals of 2 in liquid benzene at room temperature for 16 h leads to single crystals of inclusion compound [Zn4(dmf)(ur)2(ndc)4]·6C6H6 (3). The framework structure of benzene adduct 3 is practically identical to one in 1. In both cases, a presence of guest molecules distorts the framework symmetry and space group is changed back to P21/n. A space within the channels is occupied by benzene molecules (Fig. 6).
#
# There are no strong contacts between guest benzene molecules except for specific C–H ◊◊◊p interactions (Fig. S6†), which are common in such aryl molecules packing.7 We also found some weak H-bonds between CH group of benzene and carboxyl group of ndc2- ligand. The host–guest adduct with ferrocene was prepared by heating a mixture of single crystals of 2 and solid ferrocene in an evacuated sealed glass tube at 100 ◦C for 10 h. After slow cooling to room temperature, yellow crystals of
# [Zn4(dmf)(ur)2(ndc)4]·4Fe(C5H5)2 (4) were separated from excess of the ferrocene. Noteworthy, the corresponding ferrocene adduct cannot be obtained by a reaction of 2 with ferrocene solution in cyclohexane. As identified from the single-crystal X-ray diffraction data, the ferrocene-imbued framework of host–guest system 4 has less distorted monoclinic Cc space group symmetry compared to that in 3 (Fig. 7). The most significant difference in 4 is that the all three ndc2- ligands are coordinated to Zn(4) atom on monodentate manner, whereas in 1–3 one ndc2- ligand is always bidentate. As a result, Zn(4) in structure 4 has distorted trigonal bipyramidal coordination environment in contrast to distorted octahedral one in 1–3 (Fig. S7†). A space within the channels is occupied by ferrocene molecules of four crystallographically independent types. Interestingly, one of them is disordered over two positions with the site occupancy factors being 0.32 and 0.68 (Fig. S8†). Except for van-der-Waals contacts, we could not identify any specific interactions between ferrocene molecules and the framework, as well as between guest molecules. We note here, that the framework stability and phase purity of guest-exchange compounds 3 and 4 were independently confirmed by X-ray powder diffraction method (Fig. S9†).
#
# The solid-state photoluminescence properties of complexes 1–4 were investigated at room temperature (Fig. 8, Fig. S10†).
#
# Their emissions spectra were collected from 380 nm to 600 nm with excitation wavelength at l = 370 nm. The positions of maxima of the photoluminescence spectra for the materials 1–3 are the identical. Some deviations in the luminescence intensities for these materials could be attributed to the method errors. All compounds 1–3 exhibit strong blue emission with broad maximum at l = 430 nm which can be assigned to naphtalenedicarboxylate (ndc2-) intraligand emission p–p*. However, the presence of ferrocene in the host–guest compound 4 essentially quenches the photoluminescence of the framework. In fact, the ferrocene molecule and its derivatives have been widely used as a luminescence quenchers,8 particularly, because of their high stability under visible irradiation and capacity to inhibit the lowest energy excited states (generally, the triplet state).9 Such photoluminescence quenching led to numerous applications in the areas of analytical chemistry, molecular organized systems and biology.10 The excitation energy is transferred to the ferrocene FeCp2, followed by the thermal relaxation of the excited FeCp2* state. There are two possible luminescence quenching mechanisms, known as energy transfer and electron transfer.9 The later is unlikely, because it should involve electron transfer from the ferrocene to exited anionic ligand, forming intermediate radical species ndc3-∑, which should be very unstable. The energy transfer mechanism requires the luminescence radiation energy to be higher, than the energy of the first exited state of ferrocene FeCp2*, which is 21800 cm-1. As mentioned above, the emitted radiation wavelength of p–p* transitions in ndc2- has maximum at l = 430 nm (or 23250 cm-1), which is just enough to promote the ferrocene excitation and effectively absorb the framework photoluminescence. Therefore, we believe that observed quenching of the metal–organic framework luminescence by the ferrocene follows the energy transfer mechanisms. The unique combination of the pronounced guest-dependant photoluminescence, great framework stability and potent sorption capability of microporous metal–organic material [Zn4(dmf)(ur)2(ndc)4] makes is very strong candidate for practical sensing applications for aromatic or other compounds. More experiments are currently under way in order to investigate the relations between host–guest interactions and luminescence properties of such supramolecular compounds.
#
# ## Conclusions
#
# A novel microporous Zn(II) metal–organic framework with permanent porosity has been synthesized and structurally characterized. It is shown that as-synthesized form of this MOF-material retains its single crystallinity after guest molecules removal or exchange. The permanent porosity was further confirmed by nitrogen and hydrogen sorption data. Additionally, the pronounced guest-depended photoluminescence properties have been demonstrated, which open great possibilities to use this material for practical sensing applications.
#
# ## Experimental General Remarks
#
# All chemicals purchased were of reagent grade and were used as received without further purification. Methylene chloride was purified according to standard procedure. FTIR spectra (KBr pellets) were recorded in the range of 4000–400 cm-1 on a Scimitar FTS 2000 Fourier-transform infrared spectrometer. Powder X-ray diffraction (PXRD) data were collected with Cu-Ka radiation on a Philips PW 1830 instrument equipped with a PW 1820 vertical Bragg–Brentano powder goniometer and a PW 1710 control unit.
#
# ![5_image_0.png](5_image_0.png)
#
# ![6_image_0.png](6_image_0.png)
#
# Thermogravimetric analysis (TGA) was carried out at a ramp rate of 10 ◦C min-1 in a helium atmosphere with a NETZSCH
# TG 209 F1 instrument. Elemental analyses on C, H, and N
# were performed on a Euro EA 3000 CHN Elemental Analyzer.
#
# Fluorescence emission spectra were collected on a Varian Cary Eclipse spectrofluorimeter.
#
# ## Synthesis
#
# [Zn4(dmf)(ur)2(ndc)4]·5DMF·**H2O (1).** A mixture of Zn(NO3)2·6H2O (0.300 g, 1.00 mmol), 2,6-naphtalenedicarboxylic acid (0.216 g, 1.00 mmol), and urotropine (0.070 g, 0.50 mmol)
# in DMF (25 mL) was heated at 100 ◦C for 10 h in teflon-lined capped container under autogenous pressure. After slow cooling to room temperature, colorless crystals of 1 were separated by filtration, washed with DMF, and then diethylether and dried on air. Yield 0.434 g (28%). Anal: Calc. for C78H92N14O23Zn4 (%) C
# 50.5; H 5.0; N 10.6. Found (%): C 49.9; H 5.2; N 10.6. IR (KBr, cm-1): 3435 (w), 3060 (w), 2928 (w), 1666 (s), 1616 (m), 1585 (m),
# 1496 (w), 1408 (s), 1356 (m), 1251 (w), 1227 (w), 1196 (w), 1096 (w), 1027 (m), 993 (m), 922 (w), 836 (w), 784 (s), 730 (w), 660 (w),
# 588 (w), 481 (m). TGA data: calc. weight loss for 5DMF + H2O:
# 21%; found: 21%.
#
# [Zn4(dmf)(ur)2(ndc)4] (2). The crystals of 1 (0.100 g, 0.056 mmol) were immersed into dried CH2Cl2 (15 mL) for 72 h,
#
# | Table 1                                  | Crystal data and structure refinement for 1–4   |                                          |                    |                    |
# |------------------------------------------|-------------------------------------------------|------------------------------------------|--------------------|--------------------|
# | Compounds                                | 1                                               | 2                                        | 3                  | 4                  |
# | Empirical formula                        | C78H92N14O23Zn4                                 | C63H55N9O17Zn4                           | C99H91N9O17Zn4     | C103H95N9O17Zn4Fe4 |
# | Formula weight                           | 1855.14                                         | 1471.64                                  | 1940.29            | 2215,76            |
# | T/K                                      | 150(2)                                          | 150(2)                                   | 150(2)             | 130(2)             |
# | Crystal system                           | Monoclinic                                      | Monoclinic                               | Monoclinic         | Monoclinic         |
# | Space group                              | P21/n                                           | Cc                                       | P21/n              | Cc                 |
# | a/A˚                                     | 12.3274(5)                                      | 24.8414(6)                               | 12.2527(2)         | 24.6659(7)         |
# | b/A˚                                     | 30.5413(19)                                     | 31.1031(8)                               | 31.2515(5)         | 31.3085(12)        |
# | c/A˚                                     | 24.7472(15)                                     | 12.3400(3)                               | 24.7184(4)         | 12.2751(5)         |
# | b/◦                                      | 98.232(1)                                       | 97.318(1)                                | 97.023(1)          | 96.306(1)          |
# | Volume/A˚ 3                              | 9221.2(9)                                       | 9456.8(4)                                | 9394.0(3)          | 9422.1(6)          |
# | Z                                        | 4                                               | 4                                        | 4                  | 4                  |
# | Dcalc/g cm-3                             | 1.336                                           | 1.034                                    | 1.372              | 1.562              |
# | Absorbtion coefficient/mm-1              | 1.103                                           | 1.054                                    | 1.080              | 1.672              |
# | F(000)                                   | 3848                                            | 3008                                     | 4016               | 4544               |
# | Crystal size/mm                          | 0.32 ¥ 0.11 ¥ 0.07                              | 0.36 ¥ 0.16 ¥ 0.14                       | 0.20 ¥ 0.18 ¥ 0.12 | 0,09 ¥ 0,08 ¥ 0,06 |
# | q for data collection/◦                  | 1.79–26.39                                      | 2.11–30,54                               | 2.06–30.52         | 2.12–27.53         |
# | Limiting indices                         | -15 £ h £ 8, -38 £ k £ 38, -30 £ l £ 30         | -31 £ h £ 18, -40 £ k £ 40, -15 £ l £ 15 |                    |                    |
# | Reflns collected/unique                  | 57408/18509                                     | 61839/25216                              | 125023/28654       | 36506/17100        |
# | Rint                                     | 0.0555                                          | 0.0171                                   | 0.0279             | 0.0335             |
# | Goodness-of-fit on F2                    | 1.104                                           | 1.097                                    | 1.037              | 1.023              |
# | Absolute structure parameter             | -                                               | 0.472(8)                                 | -                  | 0.488(7)           |
# | Final R indices [I > 2s(I)]              | R1 = 0.1079                                     | R1 = 0.0374                              | R1 = 0.0367        | R1 = 0.0349        |
# | wR2 = 0.2833                             | wR2 = 0.1271                                    | wR2 = 0.0879                             | wR2 = 0.0672       |                    |
# | R indices (all data)                     | R1 = 0.1451                                     | R1 = 0.0423                              | R1 = 0.0492        | R1 = 0.0482        |
# | wR2 = 0.2973                             | wR2 = 0.1311                                    | wR2 = 0.0916                             | wR2 = 0.0706       |                    |
# | Largest diff. peak and hole/e A˚ -3      | 1.704/-0.950                                    | 1.230/-0.406                             | 0.980/-0.795       | 0.811/-0.850       |
# | -35 £ h £ 31, -44 £ k £ 40, -16 £ l £ 17 | -17 £ h £ 17, -44 £ k £ 39, -35 £ l £ 32        |                                          |                    |                    |
#
# ![7_image_0.png](7_image_0.png)
#
# and then heated under dynamic vacuum at 65 ◦C for 24 h. Anal:
# Calc. for C63H55N9O17Zn4 (%): C 51.4; H 3.8; N 8.6. Found (%): C
# 51,7; H 3,8; N 8,7.
#
# [Zn4(dmf)(ur)2(ndc)4]·6C6H6 **(3).** The crystals of 2 (0.100 g, 0.068 mmol) were immersed in benzene (10 ml) for 72 h. After that, colorless crystals of 3 was separated by filtration, and dried on air. Anal: Calc. for C99H91N9O17Zn4 (%): C 61.3; H 4.7; N 6.5.
#
# Found (%): C 60.9; H 4.4; N 6.7.
#
# [Zn4(dmf)(ur)2(ndc)4]·4Fe(C5H5)2 **(4).** A mixture of crystals of 2 (0.050 g, 0.034 mmol), and ferrocene (0.025 g, 0.136 mmol) was heated in evacuated sealed glass tube at 100 ◦C for 10 h. After slow cooling to room temperature, yellow crystals of 4 were separated from excess of ferrocene crystallized on the inner side wall of glass tube. Anal: Calc. for C103H95N9O17Zn4Fe4 (%): C 55.8; H 4.3; N
# 5.7. Found (%): C 55.7; H 4.4; N 5.7.
#
# ## Gas Sorption Measurements
#
# The dichloromethylene-exchanged sample 1 was activated in vacuum at 100 ◦C for 14 h. Nitrogen adsorption at 77 K was studied by means of Autosorb-6B-Kr (Quantachrome) instrument. Prior to experiment the MOF was degassed under dynamic vacuum (30 mTorr) at 80 ◦C overnight. Adsorption isotherm was measured in a range of 10-5 < P/P0 < 0.995. Pore volume-size distribution was calculated using standard regularization procedure with kernel functions, calculated using NLDFT for silica cylindrical pores. Despite on obvious model restrictions, the calculated isotherm fitted well the experimental one, and the characteristic sizes from pore volume-size distributions correlate with the sizes from X-ray diffraction data. The hydrogen sorption isotherms were measured on BELSORP-max instrument using high-purity gas (99.9999%)
# in the range 0.0–1.0 bar at 77 K (liq. N2 bath) and 87 K (liq. Ar bath). Enthalpies of H2 adsorption were calculated using a variant of the Clausius–Clapeyron equation: ln(P1/P2) = DHads(T2 - T1)/(RT1T2), where Pn - pressure for isotherm n, Tn - temperature for isotherm n, R = 8.3145 J/(mol K). Pressure as a function of the amount adsorbed was determined using the Langmuir–Freundlich fit for each isotherm (see ESI† for details).11
#
# ## X-Ray Crystallography
#
# Single-crystal XRD data collections of 1–4 were performed by using an automated four circle Bruker–Nonius X8Apex CCD
# diffractometer with Mo-Ka radiation (l = 0.71073 A˚ ). An absorbtion correction was applied based on the intensities of equivalent reflections with the use of the SADABS 12 program.
#
# The structures were solved by direct method and refined on F2 by full-matrix least-squares method in the anisotropic approximation (for non-hydrogen atoms) using SHELX-97 program package.13 Positions of the hydrogen atoms of 2,6-naphtalenedicarboxylate, and urotropine ligands, guest benzene, ferrocene and DMF
# molecules were calculated geometrically and refined by the rigid model. The hydrogen atoms of disordered guest water molecules in 1 were not located. In the case of 2 and 4 a racemic merohedral twinning was found with the twinning law of {-1, 0, 0; 0, -1, 0; 0, 0, -1} with relative component weights of 0.528(8)/0.472(8) for 2, and 0.512(7)/0.488(7) for 4. X-ray data collections have been performed for several crystals of 1. The data given for 1 in the paper are the best we could achieve. Apparently, lower quality of X-ray data of 1 is due to non-ideal crystal quality and disordering in guest subsystem. A summary of the crystallographic data and structural determination for 1–4 is provided in Table 1. Selected bond length and angles are listed in Tables S1–S4 (see ESI†).

# %% [markdown]
# Document specific text chunking strategies will be used - ie. Langchains "MarkdownTextSplitter"
#
# Similar to recursive text splitting, but a step up.

# %%
from langchain.text_splitter import MarkdownTextSplitter
splitter = MarkdownTextSplitter(chunk_size = 2000, chunk_overlap=0)

# %%
chunks = splitter.create_documents([text])

# %%
chunks[0]
# Out:
# Document(page_content='This article is published as part of the *Dalton Transactions* **themed issue entitled:** \n\n# New Talent Asia\n\nHighlighting the excellent work being carried out by younger members of the inorganic academic community in Asia Guest Editor Masahiro Yamashita Tohoku University, Japan Published in issue 10, 2011 of *Dalton Transactions*\n\n![0_image_0.png](0_image_0.png)\n\nImage reproduced with permission of Kenneth Kam-Wing Lo Articles in the issue include: PERSPECTIVES: Pyrazolin-4-ylidenes: a new class of intriguing ligands Yuan Han and Han Vinh Huynh, *Dalton Trans*., 2011, DOI: 10.1039/C0DT01037E Solvent induced molecular magnetic changes observed in single-crystal-to-single-crystal transformation Zheng-Ming Hao and Xian-Ming Zhang, *Dalton Trans*., 2011, DOI: 10.1039/C0DT00979B, ARTICLES: \nNegative thermal expansion emerging upon structural phase transition in ZrV2O7 and HfV2O7 Yasuhisa Yamamura, Aruto Horikoshi, Syuma Yasuzuka, Hideki Saitoh and Kazuya Saito Dalton Trans., 2011, DOI: 10.1039/C0DT01087A \nPreparation of surface molecularly imprinted Ru-complex catalysts for asymmetric transfer hydrogenation in water media Zhihuan Weng, Satoshi Muratsugu, Nozomu Ishiguro, Shin-ichi Ohkoshi and Mizuki Tada Dalton Trans., 2011, DOI: 10.1039/C0DT00950D \nVisit the *Dalton Transactions* website for more cutting-edge inorganic and organometallic research www.rsc.org/dalton\n\n# Microporous Sensor: Gas Sorption, Guest Exchange And Guest-Dependant Luminescence Of Metal–Organic Framework†')

# %% [markdown]
# ### Extracting Nodes and Relationships
#
# Could use two approaches:
# - Loop through each chunk with the LLM to extract the KG info (nodes,relationships, properties)
# - Employ a vector databse and do similarity search based off a query, then only look through those chunks
#
# I will begin with the first approach. If its not too time consuming/expensive, I think it would be best.

# %% [markdown]
# LLMGraphTransformer from langchain will be used to extract entities from unstructured text. Providing a predefined schema is optional. However, you cannot provide a description/more context related to your schema.
#
# I think it would be useful to provide some MOF-related context to ensure the LLM knows what it is looking for. Maybe modifying the system prompt in the Langchain code base could help. We could pass an optional "schema description" variable where we provide additional context. We just have to be careful about exceeding the context window of our LLM. If possible, maybe we could pass an optional description for each part of a schema, ie. you can choose to further describe a Node type or relationship, so the LLM better understands what to look for.
#
# LLMGraph transformer has an optional "Prompt" input, maybe this can be used to provide additional context.

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(temperature=0, model_name="gpt-4o-mini")
llm_transformer = LLMGraphTransformer(
  llm=llm, 
  #node_properties=["description"], I dont think we need node properties. And "Description" is probably too vague
  #relationship_properties=["description"]
)

# %%
from typing import List
from langchain_community.graphs.graph_document import GraphDocument
from langchain_core.documents import Document

def process_document(doc: Document) -> List[GraphDocument]:
    return llm_transformer.convert_to_graph_documents([doc])

# %%
# Process each chunk using the process_text function
graph_documents = []
for chunk in chunks:
    graph_document = process_document(chunk)
    graph_documents.extend(graph_document)

# Print or handle the processed graph_documents as needed
print(f"Processed {len(graph_documents)} GraphDocuments.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       2 graph_documents = []
#       3 for chunk in chunks:
# ----> 4     graph_document = process_document(chunk)
#       5     graph_documents.extend(graph_document)
#       7 # Print or handle the processed graph_documents as needed
#
# Cell In[7], line 6, in process_document(doc)
#       5 def process_document(doc: Document) -> List[GraphDocument]:
# ----> 6     return llm_transformer.convert_to_graph_documents([doc])
#
# File c:\Users\tompr\miniconda3\envs\general\Lib\site-packages\langchain_experimental\graph_transformers\llm.py:782, in LLMGraphTransformer.convert_to_graph_documents(self, documents, config)
#     770 def convert_to_graph_documents(
#     771     self, documents: Sequence[Document], config: Optional[RunnableConfig] = None
#     772 ) -> List[GraphDocument]:
#     773     """Convert a sequence of documents into graph documents.
#     774
#     775     Args:
#    (...)
#     780         Sequence[GraphDocument]: The transformed documents as graphs.
#     781     """
# --> 782     return [self.process_response(document, config) for document in documents]
#
# File c:\Users\tompr\miniconda3\envs\general\Lib\site-packages\langchain_experimental\graph_transformers\llm.py:722, in LLMGraphTransformer.process_response(self, document, config)
#     717 """
#     718 Processes a single document, transforming it into a graph document using
#     719 an LLM based on the model's schema and constraints.
#     720 """
#     721 text = document.page_content
# --> 722 raw_schema = self.chain.invoke({"input": text}, config=config)
#     723 if self._function_call:
#     724     raw_schema = cast(Dict[Any, Any], raw_schema)
#
# File c:\Users\tompr\miniconda3\envs\general\Lib\site-packages\langchain_core\runnables\base.py:2875, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2873             input = step.invoke(input, config, **kwargs)
#    2874         else:
# -> 2875             input = step.invoke(input, config)
#    2876 # finish the root run
#    2877 except BaseException as e:
#
# File c:\Users\tompr\miniconda3\envs\general\Lib\site-packages\langchain_core\runnables\base.py:3562, in RunnableParallel.invoke(self, input, config)
#    3549     with get_executor_for_config(config) as executor:
#    3550         futures = [
#    3551             executor.submit(
#    3552                 step.invoke,
#    (...)
#    3560             for key, step in steps.items()
#    3561         ]
# -> 3562         output = {key: future.result() for key, future in zip(steps, futures)}
#    3563 # finish the root run
#    3564 except BaseException as e:
#
# File c:\Users\tompr\miniconda3\envs\general\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File c:\Users\tompr\miniconda3\envs\general\Lib\threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
graph_documents
# Out:
# [GraphDocument(nodes=[Node(id='Dalton Transactions', type='Publication'), Node(id='New Talent Asia', type='Themed issue'), Node(id='Masahiro Yamashita', type='Person'), Node(id='Tohoku University', type='Institution'), Node(id='Yuan Han', type='Person'), Node(id='Han Vinh Huynh', type='Person'), Node(id='Zheng-Ming Hao', type='Person'), Node(id='Xian-Ming Zhang', type='Person'), Node(id='Yasuhisa Yamamura', type='Person'), Node(id='Aruto Horikoshi', type='Person'), Node(id='Syuma Yasuzuka', type='Person'), Node(id='Hideki Saitoh', type='Person'), Node(id='Kazuya Saito', type='Person'), Node(id='Zhihuan Weng', type='Person'), Node(id='Satoshi Muratsugu', type='Person'), Node(id='Nozomu Ishiguro', type='Person'), Node(id='Shin-Ichi Ohkoshi', type='Person'), Node(id='Mizuki Tada', type='Person')], relationships=[Relationship(source=Node(id='New Talent Asia', type='Themed issue'), target=Node(id='Dalton Transactions', type='Publication'), type='PART_OF'), Relationship(source=Node(id='Masahiro Yamashita', type='Person'), target=Node(id='Tohoku University', type='Institution'), type='AFFILIATED_WITH'), Relationship(source=Node(id='Yuan Han', type='Person'), target=Node(id='Dalton Transactions', type='Publication'), type='CONTRIBUTED_TO'), Relationship(source=Node(id='Han Vinh Huynh', type='Person'), target=Node(id='Dalton Transactions', type='Publication'), type='CONTRIBUTED_TO'), Relationship(source=Node(id='Zheng-Ming Hao', type='Person'), target=Node(id='Dalton Transactions', type='Publication'), type='CONTRIBUTED_TO'), Relationship(source=Node(id='Xian-Ming Zhang', type='Person'), target=Node(id='Dalton Transactions', type='Publication'), type='CONTRIBUTED_TO'), Relationship(source=Node(id='Yasuhisa Yamamura', type='Person'), target=Node(id='Dalton Transactions', type='Publication'), type='CONTRIBUTED_TO'), Relationship(source=Node(id='Aruto Horikoshi', type='Person'), target=Node(id='Dalton Transactions', type='Publication'), type='CONTRIBUTED_TO'), Relationship(source=Node(id='Syuma Yasuzuka', type='Person'), target=Node(id='Dalton Transactions', type='Publication'), type='CONTRIBUTED_TO'), Relationship(source=Node(id='Hideki Saitoh', type='Person'), target=Node(id='Dalton Transactions', type='Publication'), type='CONTRIBUTED_TO'), Relationship(source=Node(id='Kazuya Saito', type='Person'), target=Node(id='Dalton Transactions', type='Publication'), type='CONTRIBUTED_TO'), Relationship(source=Node(id='Zhihuan Weng', type='Person'), target=Node(id='Dalton Transactions', type='Publication'), type='CONTRIBUTED_TO'), Relationship(source=Node(id='Satoshi Muratsugu', type='Person'), target=Node(id='Dalton Transactions', type='Publication'), type='CONTRIBUTED_TO'), Relationship(source=Node(id='Nozomu Ishiguro', type='Person'), target=Node(id='Dalton Transactions', type='Publication'), type='CONTRIBUTED_TO'), Relationship(source=Node(id='Shin-Ichi Ohkoshi', type='Person'), target=Node(id='Dalton Transactions', type='Publication'), type='CONTRIBUTED_TO'), Relationship(source=Node(id='Mizuki Tada', type='Person'), target=Node(id='Dalton Transactions', type='Publication'), type='CONTRIBUTED_TO')], source=Document(page_content='This article is published as part of the *Dalton Transactions* **themed issue entitled:** \n\n# New Talent Asia\n\nHighlighting the excellent work being carried out by younger members of the inorganic academic community in Asia Guest Editor Masahiro Yamashita Tohoku University, Japan Published in issue 10, 2011 of *Dalton Transactions*\n\n![0_image_0.png](0_image_0.png)\n\nImage reproduced with permission of Kenneth Kam-Wing Lo Articles in the issue include: PERSPECTIVES: Pyrazolin-4-ylidenes: a new class of intriguing ligands Yuan Han and Han Vinh Huynh, *Dalton Trans*., 2011, DOI: 10.1039/C0DT01037E Solvent induced molecular magnetic changes observed in single-crystal-to-single-crystal transformation Zheng-Ming Hao and Xian-Ming Zhang, *Dalton Trans*., 2011, DOI: 10.1039/C0DT00979B, ARTICLES: \nNegative thermal ex ...
#  GraphDocument(nodes=[Node(id='Sergey A. Sapchenko', type='Person'), Node(id='Denis G. Samsonenko', type='Person'), Node(id='Danil N. Dybtsev', type='Person'), Node(id='Maxim S. Melgunov', type='Person'), Node(id='Vladimir P. Fedina', type='Person'), Node(id='Zn(Ii)-Containing Metal–Organic Framework', type='Material'), Node(id='X-Ray Crystallography', type='Technique'), Node(id='Gas Sorption Analysis', type='Technique'), Node(id='2,6-Naphtalenedicarboxylate', type='Chemical'), Node(id='Urotropin', type='Chemical'), Node(id='N,N¢-Dimethylformamide', type='Chemical'), Node(id='Benzene', type='Chemical'), Node(id='Ferrocene', type='Chemical')], relationships=[Relationship(source=Node(id='Sergey A. Sapchenko', type='Person'), target=Node(id='Denis G. Samsonenko', type='Person'), type='COAUTHOR'), Relationship(source=Node(id='Sergey A. Sapchenko', type='Person'), target=Node(id='Danil N. Dybtsev', type='Person'), type='COAUTHOR'), Relationship(source=Node(id='Sergey A. Sapchenko', type='Person'), target=Node(id='Maxim S. Melgunov', type='Person'), type='COAUTHOR'), Relationship(source=Node(id='Sergey A. Sapchenko', type='Person'), target=Node(id='Vladimir P. Fedina', type='Person'), type='COAUTHOR'), Relationship(source=Node(id='Zn(Ii)-Containing Metal–Organic Framework', type='Material'), target=Node(id='X-Ray Crystallography', type='Technique'), type='CHARACTERIZED_BY'), Relationship(source=Node(id='Zn(Ii)-Containing Metal–Organic Framework', type='Material'), target=Node(id='Gas Sorption Analysis', type='Technique'), type='CHARACTERIZED_BY'), Relationship(source=Node(id='Zn(Ii)-Containing Metal–Organic Framework', type='Material'), target=Node(id='2,6-Naphtalenedicarboxylate', type='Chemical'), type='CONTAINS'), Relationship(source=Node(id='Zn(Ii)-Containing Metal–Organic Framework', type='Material'), target=Node(id='Urotropin', type='Chemical'), type='CONTAINS'), Relationship(source=Node(id='Zn(Ii)-Containing Metal–Organic Framework', type='Material'), target=Node(id='N,N¢-Dimethylformamide', type='Chemical'), type='CONTAINS'), Relationship(source=Node(id='Zn(Ii)-Containing Metal–Organic Framework', type='Material'), target=Node(id='Benzene', type='Chemical'), type='HOST_GUEST_SYSTEM'), Relationship(source=Node(id='Zn(Ii)-Containing Metal–Organic Framework', type='Material'), target=Node(id='Ferrocene', type='Chemical'), type='HOST_GUEST_SYSTEM')], source=Document(page_content='Sergey A. Sapchenko,a Denis G. Samsonenko,*a,b Danil N. Dybtsev,a,c Maxim S. Melgunovd and Vladimir P. Fedina,b Received 12th August 2010, Accepted 14th October 2010 DOI: 10.1039/c0dt00999g Zn(II)-containing metal–organic framework (MOF) [Zn4(dmf)(ur)2(ndc)4] (ndc2- =\n2,6-naphtalenedicarboxylate, ur = urotropin, dmf = N,N¢-dimethylformamide) was synthesized and characterized by X-ray crystallography and gas sorption analysis. Host MOF retains its crystallinity after guest removal and exchange. Single-crystal to single-crystal formation of different host–guest systems with benzene and ferrocene was investigated. Interesting guest-depended luminescence properties of the porous host framework were observed.\n\n## Introduction')),
#  GraphDocument(nodes=[Node(id='Metal–Organic Coordination Polymers', type='Concept'), Node(id='Metal Ions', type='Concept'), Node(id='Organic Bridging Ligands', type='Concept'), Node(id='Metal Coordination Complexes', type='Concept'), Node(id='Extended Metal–Organic Framework', type='Concept'), Node(id='Novel Compounds', type='Concept'), Node(id='Sorption', type='Concept'), Node(id='Catalytic Activity', type='Concept'), Node(id='Luminescence', type='Concept'), Node(id='Magnetism', type='Concept'), Node(id='Gas Sorption', type='Concept'), Node(id='Chemical Sensing', type='Concept'), Node(id='Porous Metal–Organic Frameworks', type='Concept'), Node(id='Guest-Related Transitions', type='Concept'), Node(id='Porous Channels', type='Concept'), Node(id='Functional Guest Species', type='Concept'), Node(id='Host–Guest Complexes', type='Concept'), Node(id='Guest Molecule', type='Concept'), Node(id='Porous Framework', type='Concept'), Node(id='Sensing Mechanism', type='Concept')], relationships=[Relationship(source=Node(id='Metal–Organic Coordination Polymers', type='Concept'), target=Node(id='Metal Ions', type='Concept'), type='CONSTRUCTED_FROM'), Relationship(source=Node(id='Metal–Organic Coordination Polymers', type='Concept'), target=Node(id='Organic Bridging Ligands', type='Concept'), type='CONSTRUCTED_FROM'), Relationship(source=Node(id='Metal Coordination Complexes', type='Concept'), target=Node(id='Extended Metal–Organic Framework', type='Concept'), type='UNITE_INTO'), Relationship(source=Node(id='Extended Metal–Organic Framework', type='Concept'), target=Node(id='Novel Compounds', type='Concept'), type='LEAD_TO'), Relationship(source=Node(id='Novel Compounds', type='Concept'), target=Node(id='Sorption', type='Concept'), type='FEATURE'), Relationship(source=Node(id='Novel Compounds', type='Concept'), target=Node(id='Catalytic Activity', type='Concept'), type='FEATURE'), Relationship(source=Node(id='Novel Compounds', type='Concept'), target=Node(id='Luminescence', type='Concept'), type='FEATURE'), Relationship(source=Node(id='Novel Compounds', type='Concept'), target=Node(id='Magnetism', type='Concept'), type='FEATURE'), Relationship(source=Node(id='Metal–Organic Frameworks', type='Concept'), target=Node(id='Gas Sorption', type='Concept'), type='DEPENDS_ON'), Relationship(source=Node(id='Metal–Organic Frameworks', type='Concept'), target=Node(id='Catalytic Activity', type='Concept'), type='DEPENDS_ON'), Relationship(source=Node(id='Metal–Organic Frameworks', type='Concept'), target=Node(id='Guest Composition', type='Concept'), type='DEPENDS_ON'), Relationship(source=Node(id='Porous Metal–Organic Frameworks', type='Concept'), target=Node(id='Guest-Related Transitions', type='Concept'), type='CAPABLE_OF_SWITCHING'), Relationship(source=Node(id='Porous Metal–Organic Frameworks', type='Concept'), target=Node(id='Porous Channels', type='Concept'), type='FEATURE'), Relationship(source=Node(id='Porous Metal–Organic Frameworks', type='Concept'), target=Node(id='Functional Guest Species', type='Concept'), type='ACCOMMODATE'), Relationship(source=Node(id='Porous Metal–Organic Frameworks', type='Concept'), target=Node(id='Porous Framework', type='Concept'), type='MAINTAIN_POROSITY_DURING'), Relationship(source=Node(id='Host–Guest Complexes', type='Concept'), target=Node(id='Guest Molecule', type='Concept'), type='INVESTIGATE_INTERACTIONS_WITH'), Relationship(source=Node(id='Host–Guest Complexes', type='Concept'), target=Node(id='Porous Framework', type='Concept'), type='INVESTIGATE_INTERACTIONS_WITH'), Relationship(source=Node(id='Host–Guest Complexes', type='Concept'), target=Node(id='Sensing Mechanism', type='Concept'), type='ELUCIDATES')], source=Document(page_content='Metal–organic coordination polymers constructed from metal ions and organic bridging ligands have attracted considerable attention in recent years.1 The wide variety of organic ligands and practically infinite number of ways to unite metal coordination complexes into extende ...
#  GraphDocument(nodes=[Node(id='Single-Crystal X-Ray Diffraction Technique', type='Concept'), Node(id='Guest Disorder Problem', type='Concept'), Node(id='Fragility Of Metal-Organic Single Crystals', type='Concept'), Node(id='Porous Metal–Organic Coordination Polymer', type='Concept'), Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O (1)', type='Compound'), Node(id='Dmf', type='Solvent'), Node(id='Gas Sorption', type='Concept'), Node(id='Guest-Free Samples', type='Concept'), Node(id='Guest-Exchanged Samples', type='Concept'), Node(id='Luminescent Properties', type='Concept'), Node(id='Benzene', type='Molecule'), Node(id='Ferrocene', type='Molecule'), Node(id='Zn(No3)2·6H2O', type='Compound'), Node(id='2,6-Naphtalenedicarboxylic Acid (H2Ndc)', type='Compound'), Node(id='Urotropin (Ur)', type='Compound'), Node(id='Monoclinic System', type='Concept'), Node(id='Space Group P21/N', type='Concept'), Node(id='Asymmetric Unit Of 1', type='Concept'), Node(id='Tetragonal-Pyramidal Zn(1) And Zn(2) Centers', type='Concept')], relationships=[Relationship(source=Node(id='Single-Crystal X-Ray Diffraction Technique', type='Concept'), target=Node(id='Guest Disorder Problem', type='Concept'), type='LIMITED_BY'), Relationship(source=Node(id='Single-Crystal X-Ray Diffraction Technique', type='Concept'), target=Node(id='Fragility Of Metal-Organic Single Crystals', type='Concept'), type='LIMITED_BY'), Relationship(source=Node(id='Porous Metal–Organic Coordination Polymer', type='Concept'), target=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O (1)', type='Compound'), type='DESCRIBES'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O (1)', type='Compound'), target=Node(id='Dmf', type='Solvent'), type='CONTAINS'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O (1)', type='Compound'), target=Node(id='Gas Sorption', type='Concept'), type='DEMONSTRATES'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O (1)', type='Compound'), target=Node(id='Guest-Free Samples', type='Concept'), type='CHARACTERIZED_BY'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O (1)', type='Compound'), target=Node(id='Guest-Exchanged Samples', type='Concept'), type='CHARACTERIZED_BY'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O (1)', type='Compound'), target=Node(id='Luminescent Properties', type='Concept'), type='HAS_PROPERTY'), Relationship(source=Node(id='Luminescent Properties', type='Concept'), target=Node(id='Benzene', type='Molecule'), type='ENHANCED_BY'), Relationship(source=Node(id='Luminescent Properties', type='Concept'), target=Node(id='Ferrocene', type='Molecule'), type='QUENCHED_BY'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O (1)', type='Compound'), target=Node(id='Zn(No3)2·6H2O', type='Compound'), type='OBTAINED_BY'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O (1)', type='Compound'), target=Node(id='2,6-Naphtalenedicarboxylic Acid (H2Ndc)', type='Compound'), type='OBTAINED_BY'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O (1)', type='Compound'), target=Node(id='Urotropin (Ur)', type='Compound'), type='OBTAINED_BY'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O (1)', type='Compound'), target=Node(id='Monoclinic System', type='Concept'), type='CRYSTALLIZES_IN'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O (1)', type='Compound'), target=Node(id='Space Group P21/N', type='Concept'), type='CRYSTALLIZES_IN'), Relationship(source=Node(id='Asymmetric Unit Of 1', type='Concept'), target=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O (1)', type='Compound'), type='COMPRISES'), Relationship(source=Node(id='Asymmetric Unit Of 1', type='Concept'), target=Node(id='Tetragonal-Pyramidal Zn(1) And Zn(2) Centers', type='Concept'), type='COMPRISES')], source=Document(page_content="Single-crystal X-ray diffraction technique is often limited here, because of guest disorder problem or fragility of metal-organic single crystals during the guest exchange.5 In this work w ...
#  GraphDocument(nodes=[Node(id='Metal Cation', type='Entity'), Node(id='O Atom', type='Entity'), Node(id='Ndc2-', type='Entity'), Node(id='N Atom', type='Entity'), Node(id='Urotropin', type='Entity'), Node(id='M2-Rcoo-O,O¢ Groups', type='Entity'), Node(id='Binuclear Carboxylate Complex', type='Entity'), Node(id='Zn2(Coo)4', type='Entity'), Node(id='Paddle-Wheel', type='Entity'), Node(id='Zn(Ii) Complexes', type='Entity'), Node(id='Coordination Number 5', type='Entity'), Node(id='Carboxylate Secondary Building Unit', type='Entity'), Node(id='Type B', type='Entity'), Node(id='Zn(3)', type='Entity'), Node(id='Zn(4)', type='Entity'), Node(id='Distorted Tetrahedral Zn(3) Center', type='Entity'), Node(id='Distorted Octahedral Geometry Of Zn(4) Cation', type='Entity'), Node(id='Dmf Molecule', type='Entity')], relationships=[Relationship(source=Node(id='Metal Cation', type='Entity'), target=Node(id='O Atom', type='Entity'), type='COORDINATED_BY'), Relationship(source=Node(id='Metal Cation', type='Entity'), target=Node(id='N Atom', type='Entity'), type='COORDINATED_BY'), Relationship(source=Node(id='Metal Cation', type='Entity'), target=Node(id='M2-Rcoo-O,O¢ Groups', type='Entity'), type='INTERCONNECTED_VIA'), Relationship(source=Node(id='Binuclear Carboxylate Complex', type='Entity'), target=Node(id='Zn2(Coo)4', type='Entity'), type='KNOWN_AS'), Relationship(source=Node(id='Zn2(Coo)4', type='Entity'), target=Node(id='Paddle-Wheel', type='Entity'), type='TYPE_OF'), Relationship(source=Node(id='Zn(3)', type='Entity'), target=Node(id='Distorted Tetrahedral Zn(3) Center', type='Entity'), type='COORDINATED_BY'), Relationship(source=Node(id='Zn(4)', type='Entity'), target=Node(id='Distorted Octahedral Geometry Of Zn(4) Cation', type='Entity'), type='COMPOSED_OF'), Relationship(source=Node(id='Zn(3)', type='Entity'), target=Node(id='N Atom', type='Entity'), type='COORDINATED_BY'), Relationship(source=Node(id='Zn(4)', type='Entity'), target=Node(id='N Atom', type='Entity'), type='COORDINATED_BY'), Relationship(source=Node(id='Zn(4)', type='Entity'), target=Node(id='Dmf Molecule', type='Entity'), type='COORDINATED_BY'), Relationship(source=Node(id='Zn(3)', type='Entity'), target=Node(id='Zn(Ii) Complexes', type='Entity'), type='FALLS_WITHIN'), Relationship(source=Node(id='Zn(4)', type='Entity'), target=Node(id='Zn(Ii) Complexes', type='Entity'), type='FALLS_WITHIN'), Relationship(source=Node(id='Zn(3)', type='Entity'), target=Node(id='Coordination Number 5', type='Entity'), type='FALLS_WITHIN'), Relationship(source=Node(id='Zn(4)', type='Entity'), target=Node(id='Coordination Number 5', type='Entity'), type='FALLS_WITHIN'), Relationship(source=Node(id='Carboxylate Secondary Building Unit', type='Entity'), target=Node(id='Type B', type='Entity'), type='STRUCTURE_OF')], source=Document(page_content='Each metal cation is coordinated by four O atoms of four ndc2- and one N atom of urotropin, such as these cations are interconnected via four bridging bidentate m2-RCOO-O,O¢ groups. This binuclear carboxylate complex {Zn2(COO)4}, known as "paddle-wheel",\nis very typical and common in metal carboxylate coordination structures. The Zn–O (2.006(5)–2.069(6) A˚ ) and Zn–N (2.065(6), 2.067(6) A˚ ) bond lengths found fall within the common values for Zn(II) complexes with coordination number 5. The structure of the second carboxylate secondary building unit (type B), to our best\n\n![2_image_0.png](2_image_0.png)\n\nknowledge, has never been described before and unprecedented in coordination frameworks. Contrary to the binuclear complex A, the coordination environments of Zn(3) and Zn(4) cations in B are different (Fig. 1). The distorted tetrahedral Zn(3) center is coordinated by three O atoms of three ndc2- ligands and one N atom of urotropin. The Zn(3)–O (1,899(9)–1,962(7) A˚ ) and Zn(3)–N(12) (2.111(7) A˚ ) bond lengths found fall within the common values for tetrahedral Zn(II) complexes. The distorted octahedral geometry of Zn(4) cation is composed of f ...
#  GraphDocument(nodes=[Node(id='Zn(4)', type='Metal'), Node(id='Ndc2-', type='Ligand'), Node(id='Dmf', type='Molecule'), Node(id='Zn(3)', type='Metal'), Node(id='Rcoo-O,O¢', type='Ligand'), Node(id='Urotropin', type='Ligand'), Node(id='Complex_A', type='Complex'), Node(id='Complex_B', type='Complex'), Node(id='3D_Topology', type='Topology')], relationships=[Relationship(source=Node(id='Zn(4)', type='Metal'), target=Node(id='Ndc2-', type='Ligand'), type='BONDS'), Relationship(source=Node(id='Zn(4)', type='Metal'), target=Node(id='Dmf', type='Molecule'), type='BONDS'), Relationship(source=Node(id='Zn(3)', type='Metal'), target=Node(id='Zn(4)', type='Metal'), type='LINKED'), Relationship(source=Node(id='Zn(3)', type='Metal'), target=Node(id='Rcoo-O,O¢', type='Ligand'), type='BONDS'), Relationship(source=Node(id='Zn(4)', type='Metal'), target=Node(id='Complex_A', type='Complex'), type='PART_OF'), Relationship(source=Node(id='Zn(4)', type='Metal'), target=Node(id='Complex_B', type='Complex'), type='PART_OF'), Relationship(source=Node(id='Complex_A', type='Complex'), target=Node(id='3D_Topology', type='Topology'), type='HAS_TOPOLOGY'), Relationship(source=Node(id='Complex_B', type='Complex'), target=Node(id='3D_Topology', type='Topology'), type='HAS_TOPOLOGY'), Relationship(source=Node(id='Ndc2-', type='Ligand'), target=Node(id='Complex_A', type='Complex'), type='CONNECTS'), Relationship(source=Node(id='Ndc2-', type='Ligand'), target=Node(id='Complex_B', type='Complex'), type='CONNECTS'), Relationship(source=Node(id='Urotropin', type='Ligand'), target=Node(id='Complex_A', type='Complex'), type='CONNECTS'), Relationship(source=Node(id='Urotropin', type='Ligand'), target=Node(id='Complex_B', type='Complex'), type='CONNECTS')], source=Document(page_content='There are two type of Zn(4)–O distances. The first one includes two bonds with bridging ndc2- ligands (1.982(7), 1.997(6) A˚ )\nand one of two bonds with bidentate ndc2- ligand (2.161(16)\nA˚ ). The residual bond with bidentate ndc2- ligand and bond with dmf molecule form the second type. Thereby, coordination number of Zn(4) atom can be assigned as 4 + 2. In the type B\nbuilding unit two metal cations Zn(3) and Zn(4) are interlinked via two bridging m2-RCOO-O,O¢ groups, so the overall formula of the coordination complex is {Zn2(dmf)(COO)4}. The metal–\nligand distances in both carboxylate binuclear complexes lie within typical corresponding ranges with some acceptable deviations, indicating apparent distortion.\n\nIn the structure 1 the organic ligands act as ditopic connectors between the binuclear secondary building units. Therefore, both binuclear complexes A and B could be simplified as six-connected nodes, each with distorted 4 + 2 octahedral geometry of four linear ndc2- and two angular urotropin linkers. The main difference is that urotropins are located in *trans*-positions in type A but in cis-positions in the type B node (Fig. 1). The ndc2- bridges connect nodes A and A, B and B, as well as A and B. At the same time urotropin ligands link only nodes A and B. Each type A node is connected through ndc2- to two nodes A and two nodes B\nand through urotropin to two nodes B. Similarly, each B node is connected through ndc2- to two nodes A and two B and through urotropin to two nodes A. The overall three-dimensional (3D)\ntopology of the binodal 6-connected net in the metal–organic framework 1 is very complicated (Fig. S1†), one may refer to its point symbol (3244.68.8)(3.44.53.66.8).')),
#  GraphDocument(nodes=[Node(id='Inorganic Carboxylate Complexes', type='Concept'), Node(id='Organic Ligands', type='Concept'), Node(id='Solvent Guest Molecules', type='Concept'), Node(id='1', type='Compound'), Node(id='Dmf', type='Molecule'), Node(id='H2O', type='Molecule'), Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O', type='Compound'), Node(id='Elemental Analysis', type='Method'), Node(id='Thermogravimetrical Analysis', type='Method'), Node(id='Powder X-Ray Diffraction', type='Method'), Node(id='Metal–Organic Framework', type='Concept'), Node(id='Distorted Hexagonal Channels', type='Concept'), Node(id='Ndc2-', type='Ligand'), Node(id='Urotropin', type='Ligand')], relationships=[Relationship(source=Node(id='1', type='Compound'), target=Node(id='Solvent Guest Molecules', type='Concept'), type='OCCUPIES'), Relationship(source=Node(id='1', type='Compound'), target=Node(id='Dmf', type='Molecule'), type='CONTAINS'), Relationship(source=Node(id='1', type='Compound'), target=Node(id='H2O', type='Molecule'), type='CONTAINS'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O', type='Compound'), target=Node(id='Elemental Analysis', type='Method'), type='CONFIRMED_BY'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O', type='Compound'), target=Node(id='Thermogravimetrical Analysis', type='Method'), type='CONFIRMED_BY'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O', type='Compound'), target=Node(id='Powder X-Ray Diffraction', type='Method'), type='CONFIRMED_BY'), Relationship(source=Node(id='1', type='Compound'), target=Node(id='Metal–Organic Framework', type='Concept'), type='DESTRUCTION_ASSOCIATED_WITH'), Relationship(source=Node(id='1', type='Compound'), target=Node(id='Distorted Hexagonal Channels', type='Concept'), type='OCCUPIES'), Relationship(source=Node(id='Distorted Hexagonal Channels', type='Concept'), target=Node(id='Dmf', type='Molecule'), type='CONTAINS'), Relationship(source=Node(id='Distorted Hexagonal Channels', type='Concept'), target=Node(id='H2O', type='Molecule'), type='CONTAINS'), Relationship(source=Node(id='Dmf', type='Molecule'), target=Node(id='Ndc2-', type='Ligand'), type='FORMS_H-BONDING_WITH'), Relationship(source=Node(id='H2O', type='Molecule'), target=Node(id='Urotropin', type='Ligand'), type='FORMS_H-BONDING_WITH')], source=Document(page_content='The interstitial space between inorganic carboxylate complexes and organic ligands in as-synthesized 1 is occupied by solvent guest molecules. The single-crystal X-ray diffraction analysis revealed five DMF and one H2O molecules per asymmetric unit of 1. The formula [Zn4(dmf)(ur)2(ndc)4]·5DMF·H2O was independently confirmed by elemental and thermogravimetrical\n(TG) analyses. The phase purity of 1 was also proved by powder X-ray diffraction method (See SI for the details). In particular, the TG analysis on the as-synthesized 1 indicated a gradual weight loss of 21% in the temperature range 25–300 ◦C, which is consistent with evacuation of one H2O and 5 DMF molecules. The following decrease of mass can be associated with the destruction of the metal–organic framework (Fig. S2). The guest molecules occupy distorted hexagonal channels with characteristic dimensions 9.5\n¥ 11 A˚ 2, running along a axis of 3D framework (Fig. 2). A space within channels is occupied by DMF and disordered H2O guest molecules, which form a weak H-bonding with CH or CH2 groups of ndc2- or urotropin ligands respectively, as well as with each\n\n![3_image_1.png](3_image_1.png)')),
#  GraphDocument(nodes=[Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Compound'), Node(id='P21/N', type='Space group'), Node(id='Cc', type='Space group'), Node(id='1', type='Compound'), Node(id='2', type='Compound'), Node(id='Platon 6', type='Software'), Node(id='N2', type='Gas')], relationships=[Relationship(source=Node(id='2', type='Compound'), target=Node(id='Cc', type='Space group'), type='HAS_SPACE_GROUP'), Relationship(source=Node(id='1', type='Compound'), target=Node(id='P21/N', type='Space group'), type='HAS_SPACE_GROUP'), Relationship(source=Node(id='2', type='Compound'), target=Node(id='1', type='Compound'), type='SIMILAR_TO'), Relationship(source=Node(id='2', type='Compound'), target=Node(id='Platon 6', type='Software'), type='ANALYZED_BY'), Relationship(source=Node(id='2', type='Compound'), target=Node(id='N2', type='Gas'), type='CONFIRMED_BY')], source=Document(page_content='To prepare guest-free framework [Zn4(dmf)(ur)2(ndc)4] (2) the DMF molecules was exchanged with readily volatile CH2Cl2 solvent, followed by slight heating in the dynamic vacuum. A structure of guest-free compound 2 is generally similar to 1, but there are some distinct differences. Whereas the compound 1 crystallizes in *P21/n* space group, compound 2 has slightly higher Cc symmetry. Such difference does not affect significantly Zn– O and Zn–N interatomic distances. The channels running along c axis in 2 adopt more symmetric shape than in 1 and have characteristic dimensions 10.5 ¥ 10.5 A˚ (Fig. 3). The free solvent accessible volume in 2, derived from PLATON 6 routine analysis\n(filling of the cavities with probe spheres of radius 1.2 A˚ ) was found to be 43%. Interestingly, framework 2 is not centrosymmetric\n(sp. group Cc has no inversion center) that leads to racemic merohedral twinning of the crystals 2 contrary to 1. Attempts to apply centrosymmetric space group C2/c during the refinement of 2 leads to disorder of coordinated dmf molecules over two symmetrically related positions. In case of non centrosymmetric group Cc, the disordering is not observed.\n\nThe high stability of the guest-free metal–organic framework was further confirmed by N2 sorption isotherm at 77 K for 2\n(Fig. 4), which shows type I behavior with small hysteresis and\n\n![3_image_0.png](3_image_0.png)\n\n![3_image_2.png](3_image_2.png)')),
#  GraphDocument(nodes=[Node(id='Bulk Sample', type='Material'), Node(id='Brunauer–Emmett–Teller (Bet) Surface Area', type='Measurement'), Node(id='Channels Volume-Size Distribution Diagram', type='Diagram'), Node(id='X-Ray Analysis', type='Analysis'), Node(id='Pores', type='Structure'), Node(id='H2 Uptake', type='Measurement'), Node(id='Density Of H2 In Pores', type='Measurement'), Node(id='Density Of Liquid H2', type='Measurement'), Node(id='Storage Density Of Hydrogen', type='Measurement'), Node(id='Hydrogen Isotherm', type='Measurement'), Node(id='Enthalpy Of Adsorption', type='Measurement'), Node(id='D*Hads*', type='Measurement'), Node(id='Microporous Framework 2', type='Material'), Node(id='Single Crystals Of 2', type='Material'), Node(id='Inclusion Compound [Zn4(Dmf)(Ur)2(Ndc)4]·6C6H6 (3)', type='Material'), Node(id='Framework Structure Of Benzene Adduct 3', type='Structure'), Node(id='Guest Molecules', type='Material'), Node(id='Framework Symmetry', type='Concept'), Node(id='Space Group P21/N', type='Concept')], relationships=[Relationship(source=Node(id='Bulk Sample', type='Material'), target=Node(id='Brunauer–Emmett–Teller (Bet) Surface Area', type='Measurement'), type='HAS_MEASUREMENT'), Relationship(source=Node(id='Channels Volume-Size Distribution Diagram', type='Diagram'), target=Node(id='X-Ray Analysis', type='Analysis'), type='AGREES_WITH'), Relationship(source=Node(id='Pores', type='Structure'), target=Node(id='H2 Uptake', type='Measurement'), type='HAS_MEASUREMENT'), Relationship(source=Node(id='Pores', type='Structure'), target=Node(id='Density Of H2 In Pores', type='Measurement'), type='HAS_MEASUREMENT'), Relationship(source=Node(id='Density Of Liquid H2', type='Measurement'), target=Node(id='Storage Density Of Hydrogen', type='Measurement'), type='COMPARISON'), Relationship(source=Node(id='Hydrogen Isotherm', type='Measurement'), target=Node(id='Enthalpy Of Adsorption', type='Measurement'), type='DERIVED_FROM'), Relationship(source=Node(id='D*Hads*', type='Measurement'), target=Node(id='Microporous Framework 2', type='Material'), type='RELATED_TO'), Relationship(source=Node(id='Single Crystals Of 2', type='Material'), target=Node(id='Inclusion Compound [Zn4(Dmf)(Ur)2(Ndc)4]·6C6H6 (3)', type='Material'), type='FORMS'), Relationship(source=Node(id='Framework Structure Of Benzene Adduct 3', type='Structure'), target=Node(id='Guest Molecules', type='Material'), type='DISTORTS'), Relationship(source=Node(id='Framework Symmetry', type='Concept'), target=Node(id='Space Group P21/N', type='Concept'), type='CHANGES_TO')], source=Document(page_content='thus ensuring permanent microporosity of the bulk sample. The formally calculated Brunauer–Emmett–Teller (BET) surface area is 820 m2 g-1. Channels volume-size distribution diagram (Fig. S3†)\nshows the only intense peak at 0.9 nm and agrees quantitatively with the result of X-ray analysis. The volume of these pores was calculated to be 0.2 cm3 g-1. The maximum H2 uptake for 2 at 1 atm and 77 K is 0.92 wt.% H2 (Fig. 5). Knowing pore volume, one can estimate the density of H2 in pores as 0.04 g cm-3. For comparison, density of liquid H2 at 14 K is 0.07 g cm-3. The storage density of hydrogen in the bulk sample at 1 bar is 0.009 g cm-3, which is equivalent to the density of H2 at 2.7 MPa (estimated according\n\n![4_image_0.png](4_image_0.png)\n\nto ideal gas equation) at 77 K. Additional hydrogen isotherm was measured at 87 K to determine enthalpy of adsorption derived from the Clausius–Clapeyron equation (see Fig. S4 and S5 in ESI† for details). In the interval of 0.1–1.0 wt. % of adsorbed H2, value of D*Hads* lies in the range 4.7–5.2 kJ mol-1, which is typical to other zinc–organic frameworks.2a Microporous framework 2 can form different host–guest complexes with various species ranging from diatomic molecules to organometallics. Immersing single crystals of 2 in liquid benzene at room temperature for 16 h leads to single crystals of inclusion compound [Zn4(dmf)(ur)2(n ...
#  GraphDocument(nodes=[Node(id='Benzene', type='Molecule'), Node(id='Ndc2- Ligand', type='Molecule'), Node(id='Ferrocene', type='Molecule'), Node(id='Zn4(Dmf)(Ur)2(Ndc)4·4Fe(C5H5)2', type='Compound'), Node(id='Complexes 1–4', type='Complex')], relationships=[Relationship(source=Node(id='Benzene', type='Molecule'), target=Node(id='Ndc2- Ligand', type='Molecule'), type='WEAK_BOND'), Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4·4Fe(C5H5)2', type='Compound'), target=Node(id='Ferrocene', type='Molecule'), type='HOST_GUEST_ADDUCT'), Relationship(source=Node(id='Complexes 1–4', type='Complex'), target=Node(id='Zn4(Dmf)(Ur)2(Ndc)4·4Fe(C5H5)2', type='Compound'), type='INVESTIGATED_PROPERTY')], source=Document(page_content='There are no strong contacts between guest benzene molecules except for specific C–H ◊◊◊p interactions (Fig. S6†), which are common in such aryl molecules packing.7 We also found some weak H-bonds between CH group of benzene and carboxyl group of ndc2- ligand. The host–guest adduct with ferrocene was prepared by heating a mixture of single crystals of 2 and solid ferrocene in an evacuated sealed glass tube at 100 ◦C for 10 h. After slow cooling to room temperature, yellow crystals of\n[Zn4(dmf)(ur)2(ndc)4]·4Fe(C5H5)2 (4) were separated from excess of the ferrocene. Noteworthy, the corresponding ferrocene adduct cannot be obtained by a reaction of 2 with ferrocene solution in cyclohexane. As identified from the single-crystal X-ray diffraction data, the ferrocene-imbued framework of host–guest system 4 has less distorted monoclinic Cc space group symmetry compared to that in 3 (Fig. 7). The most significant difference in 4 is that the all three ndc2- ligands are coordinated to Zn(4) atom on monodentate manner, whereas in 1–3 one ndc2- ligand is always bidentate. As a result, Zn(4) in structure 4 has distorted trigonal bipyramidal coordination environment in contrast to distorted octahedral one in 1–3 (Fig. S7†). A space within the channels is occupied by ferrocene molecules of four crystallographically independent types. Interestingly, one of them is disordered over two positions with the site occupancy factors being 0.32 and 0.68 (Fig. S8†). Except for van-der-Waals contacts, we could not identify any specific interactions between ferrocene molecules and the framework, as well as between guest molecules. We note here, that the framework stability and phase purity of guest-exchange compounds 3 and 4 were independently confirmed by X-ray powder diffraction method (Fig. S9†).\n\nThe solid-state photoluminescence properties of complexes 1–4 were investigated at room temperature (Fig. 8, Fig. S10†).')),
#  GraphDocument(nodes=[Node(id='Emissions_Spectra', type='Concept'), Node(id='380_Nm_To_600_Nm', type='Concept'), Node(id='Excitation_Wavelength', type='Concept'), Node(id='370_Nm', type='Concept'), Node(id='Photoluminescence_Spectra', type='Concept'), Node(id='Materials_1_3', type='Concept'), Node(id='Luminescence_Intensities', type='Concept'), Node(id='Method_Errors', type='Concept'), Node(id='Compounds_1_3', type='Concept'), Node(id='Blue_Emission', type='Concept'), Node(id='Maximum_430_Nm', type='Concept'), Node(id='Naphtalenedicarboxylate', type='Concept'), Node(id='Ndc2-', type='Concept'), Node(id='Ferrocene', type='Concept'), Node(id='Host_Guest_Compound_4', type='Concept'), Node(id='Photoluminescence_Quenching', type='Concept'), Node(id='Luminescence_Quenchers', type='Concept'), Node(id='High_Stability', type='Concept'), Node(id='Visible_Irradiation', type='Concept'), Node(id='Lowest_Energy_Excited_States', type='Concept'), Node(id='Triplet_State', type='Concept'), Node(id='Applications', type='Concept'), Node(id='Analytical_Chemistry', type='Concept'), Node(id='Molecular_Organized_Systems', type='Concept'), Node(id='Biology', type='Concept'), Node(id='Excitation_Energy', type='Concept'), Node(id='Ferrocene_Fecp2', type='Concept'), Node(id='Thermal_Relaxation', type='Concept'), Node(id='Excited_Fecp2*', type='Concept'), Node(id='Luminescence_Quenching_Mechanisms', type='Concept'), Node(id='Energy_Transfer', type='Concept'), Node(id='Electron_Transfer', type='Concept'), Node(id='Exited_Anionic_Ligand', type='Concept'), Node(id='Intermediate_Radical_Species_Ndc3-∑', type='Concept'), Node(id='Energy_Of_First_Exited_State', type='Concept'), Node(id='Ferrocene_Fecp2*', type='Concept'), Node(id='Emitted_Radiation_Wavelength', type='Concept'), Node(id='P–P*_Transitions', type='Concept'), Node(id='Observed_Quenching', type='Concept'), Node(id='Metal_Organic_Framework_Luminescence', type='Concept')], relationships=[Relationship(source=Node(id='Emissions_Spectra', type='Concept'), target=Node(id='380_Nm_To_600_Nm', type='Concept'), type='COLLECTED_FROM'), Relationship(source=Node(id='Excitation_Wavelength', type='Concept'), target=Node(id='370_Nm', type='Concept'), type='HAS_VALUE'), Relationship(source=Node(id='Photoluminescence_Spectra', type='Concept'), target=Node(id='Materials_1_3', type='Concept'), type='FOR'), Relationship(source=Node(id='Luminescence_Intensities', type='Concept'), target=Node(id='Materials_1_3', type='Concept'), type='ATTRIBUTED_TO'), Relationship(source=Node(id='Method_Errors', type='Concept'), target=Node(id='Luminescence_Intensities', type='Concept'), type='CONTRIBUTED_TO'), Relationship(source=Node(id='Compounds_1_3', type='Concept'), target=Node(id='Blue_Emission', type='Concept'), type='EXHIBIT'), Relationship(source=Node(id='Blue_Emission', type='Concept'), target=Node(id='Maximum_430_Nm', type='Concept'), type='HAS_MAXIMUM'), Relationship(source=Node(id='Maximum_430_Nm', type='Concept'), target=Node(id='Naphtalenedicarboxylate', type='Concept'), type='ASSIGNED_TO'), Relationship(source=Node(id='Naphtalenedicarboxylate', type='Concept'), target=Node(id='Ndc2-', type='Concept'), type='IS_TYPE_OF'), Relationship(source=Node(id='Ferrocene', type='Concept'), target=Node(id='Host_Guest_Compound_4', type='Concept'), type='QUENCHES'), Relationship(source=Node(id='Photoluminescence_Quenching', type='Concept'), target=Node(id='Luminescence_Quenchers', type='Concept'), type='IS_TYPE_OF'), Relationship(source=Node(id='Luminescence_Quenchers', type='Concept'), target=Node(id='High_Stability', type='Concept'), type='HAS_PROPERTY'), Relationship(source=Node(id='High_Stability', type='Concept'), target=Node(id='Visible_Irradiation', type='Concept'), type='UNDER'), Relationship(source=Node(id='Lowest_Energy_Excited_States', type='Concept'), target=Node(id='Triplet_State', type='Concept'), type='IS_TYPE_OF'), Relationship(source=Node(id='Photoluminescence_Quenching', type='Concept'), target=Node(id='Applications',  ...
#  GraphDocument(nodes=[Node(id='Microporous Metal–Organic Material [Zn4(Dmf)(Ur)2(Ndc)4]', type='Material'), Node(id='Aromatic Compounds', type='Compound'), Node(id='Sensing Applications', type='Application'), Node(id='Host–Guest Interactions', type='Concept'), Node(id='Luminescence Properties', type='Concept'), Node(id='Supramolecular Compounds', type='Concept')], relationships=[Relationship(source=Node(id='Microporous Metal–Organic Material [Zn4(Dmf)(Ur)2(Ndc)4]', type='Material'), target=Node(id='Sensing Applications', type='Application'), type='CANDIDATE_FOR'), Relationship(source=Node(id='Host–Guest Interactions', type='Concept'), target=Node(id='Luminescence Properties', type='Concept'), type='INVESTIGATE_RELATION'), Relationship(source=Node(id='Microporous Metal–Organic Material [Zn4(Dmf)(Ur)2(Ndc)4]', type='Material'), target=Node(id='Aromatic Compounds', type='Compound'), type='SENSING_FOR'), Relationship(source=Node(id='Supramolecular Compounds', type='Concept'), target=Node(id='Luminescence Properties', type='Concept'), type='INVESTIGATE_RELATION')], source=Document(page_content='combination of the pronounced guest-dependant photoluminescence, great framework stability and potent sorption capability of microporous metal–organic material [Zn4(dmf)(ur)2(ndc)4] makes is very strong candidate for practical sensing applications for aromatic or other compounds. More experiments are currently under way in order to investigate the relations between host–guest interactions and luminescence properties of such supramolecular compounds.')),
#  GraphDocument(nodes=[Node(id='Zn(Ii) Metal–Organic Framework', type='Material'), Node(id='Guest Molecules', type='Material'), Node(id='Nitrogen', type='Gas'), Node(id='Hydrogen', type='Gas'), Node(id='Scimitar Fts 2000 Fourier-Transform Infrared Spectrometer', type='Instrument'), Node(id='Philips Pw 1830', type='Instrument'), Node(id='Netzsch Tg 209 F1', type='Instrument'), Node(id='Euro Ea 3000 Chn Elemental Analyzer', type='Instrument'), Node(id='Varian Cary Eclipse Spectrofluorimeter', type='Instrument')], relationships=[Relationship(source=Node(id='Zn(Ii) Metal–Organic Framework', type='Material'), target=Node(id='Guest Molecules', type='Material'), type='RETURNS'), Relationship(source=Node(id='Zn(Ii) Metal–Organic Framework', type='Material'), target=Node(id='Nitrogen', type='Gas'), type='CONFIRMED_BY'), Relationship(source=Node(id='Zn(Ii) Metal–Organic Framework', type='Material'), target=Node(id='Hydrogen', type='Gas'), type='CONFIRMED_BY'), Relationship(source=Node(id='Ftir Spectra', type='Instrument'), target=Node(id='Scimitar Fts 2000 Fourier-Transform Infrared Spectrometer', type='Instrument'), type='RECORDED_ON'), Relationship(source=Node(id='Powder X-Ray Diffraction Data', type='Material'), target=Node(id='Philips Pw 1830', type='Instrument'), type='COLLECTED_WITH'), Relationship(source=Node(id='Thermogravimetric Analysis', type='Material'), target=Node(id='Netzsch Tg 209 F1', type='Instrument'), type='CARRIED_OUT_WITH'), Relationship(source=Node(id='Elemental Analyses', type='Material'), target=Node(id='Euro Ea 3000 Chn Elemental Analyzer', type='Instrument'), type='PERFORMED_ON'), Relationship(source=Node(id='Fluorescence Emission Spectra', type='Material'), target=Node(id='Varian Cary Eclipse Spectrofluorimeter', type='Instrument'), type='COLLECTED_ON')], source=Document(page_content='## Conclusions\n\nA novel microporous Zn(II) metal–organic framework with permanent porosity has been synthesized and structurally characterized. It is shown that as-synthesized form of this MOF-material retains its single crystallinity after guest molecules removal or exchange. The permanent porosity was further confirmed by nitrogen and hydrogen sorption data. Additionally, the pronounced guest-depended photoluminescence properties have been demonstrated, which open great possibilities to use this material for practical sensing applications.\n\n## Experimental General Remarks\n\nAll chemicals purchased were of reagent grade and were used as received without further purification. Methylene chloride was purified according to standard procedure. FTIR spectra (KBr pellets) were recorded in the range of 4000–400 cm-1 on a Scimitar FTS 2000 Fourier-transform infrared spectrometer. Powder X-ray diffraction (PXRD) data were collected with Cu-Ka radiation on a Philips PW 1830 instrument equipped with a PW 1820 vertical Bragg–Brentano powder goniometer and a PW 1710 control unit.\n\n![5_image_0.png](5_image_0.png)\n\n![6_image_0.png](6_image_0.png)\n\nThermogravimetric analysis (TGA) was carried out at a ramp rate of 10 ◦C min-1 in a helium atmosphere with a NETZSCH\nTG 209 F1 instrument. Elemental analyses on C, H, and N\nwere performed on a Euro EA 3000 CHN Elemental Analyzer.\n\nFluorescence emission spectra were collected on a Varian Cary Eclipse spectrofluorimeter.\n\n## Synthesis')),
#  GraphDocument(nodes=[Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Compound'), Node(id='Zn(No3)2·6H2O', type='Compound'), Node(id='2,6-Naphtalenedicarboxylic Acid', type='Compound'), Node(id='Urotropine', type='Compound'), Node(id='Dmf', type='Solvent'), Node(id='H2O', type='Solvent'), Node(id='Colorless Crystals Of 1', type='Product'), Node(id='Tga Data', type='Data'), Node(id='Ir Data', type='Data')], relationships=[Relationship(source=Node(id='Zn(No3)2·6H2O', type='Compound'), target=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Compound'), type='REACTS_WITH'), Relationship(source=Node(id='2,6-Naphtalenedicarboxylic Acid', type='Compound'), target=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Compound'), type='REACTS_WITH'), Relationship(source=Node(id='Urotropine', type='Compound'), target=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Compound'), type='REACTS_WITH'), Relationship(source=Node(id='Dmf', type='Solvent'), target=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Compound'), type='REACTS_WITH'), Relationship(source=Node(id='H2O', type='Solvent'), target=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Compound'), type='REACTS_WITH'), Relationship(source=Node(id='Colorless Crystals Of 1', type='Product'), target=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Compound'), type='RESULTS_IN'), Relationship(source=Node(id='Tga Data', type='Data'), target=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Compound'), type='ANALYZES'), Relationship(source=Node(id='Ir Data', type='Data'), target=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Compound'), type='ANALYZES')], source=Document(page_content='[Zn4(dmf)(ur)2(ndc)4]·5DMF·**H2O (1).** A mixture of Zn(NO3)2·6H2O (0.300 g, 1.00 mmol), 2,6-naphtalenedicarboxylic acid (0.216 g, 1.00 mmol), and urotropine (0.070 g, 0.50 mmol)\nin DMF (25 mL) was heated at 100 ◦C for 10 h in teflon-lined capped container under autogenous pressure. After slow cooling to room temperature, colorless crystals of 1 were separated by filtration, washed with DMF, and then diethylether and dried on air. Yield 0.434 g (28%). Anal: Calc. for C78H92N14O23Zn4 (%) C\n50.5; H 5.0; N 10.6. Found (%): C 49.9; H 5.2; N 10.6. IR (KBr, cm-1): 3435 (w), 3060 (w), 2928 (w), 1666 (s), 1616 (m), 1585 (m),\n1496 (w), 1408 (s), 1356 (m), 1251 (w), 1227 (w), 1196 (w), 1096 (w), 1027 (m), 993 (m), 922 (w), 836 (w), 784 (s), 730 (w), 660 (w),\n588 (w), 481 (m). TGA data: calc. weight loss for 5DMF + H2O:\n21%; found: 21%.\n\n[Zn4(dmf)(ur)2(ndc)4] (2). The crystals of 1 (0.100 g, 0.056 mmol) were immersed into dried CH2Cl2 (15 mL) for 72 h,')),
# ...
#  GraphDocument(nodes=[Node(id='B/◦', type='Data'), Node(id='Volume/A˚ 3', type='Data'), Node(id='Z', type='Data'), Node(id='Dcalc/G Cm-3', type='Data'), Node(id='Absorbtion Coefficient/Mm-1', type='Data'), Node(id='F(000)', type='Data'), Node(id='Crystal Size/Mm', type='Data'), Node(id='Q For Data Collection/◦', type='Data'), Node(id='Limiting Indices', type='Data'), Node(id='Reflns Collected/Unique', type='Data'), Node(id='Rint', type='Data')], relationships=[Relationship(source=Node(id='B/◦', type='Data'), target=Node(id='98.232(1)', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='B/◦', type='Data'), target=Node(id='97.318(1)', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='B/◦', type='Data'), target=Node(id='97.023(1)', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='B/◦', type='Data'), target=Node(id='96.306(1)', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Volume/A˚ 3', type='Data'), target=Node(id='9221.2(9)', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Volume/A˚ 3', type='Data'), target=Node(id='9456.8(4)', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Volume/A˚ 3', type='Data'), target=Node(id='9394.0(3)', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Volume/A˚ 3', type='Data'), target=Node(id='9422.1(6)', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Z', type='Data'), target=Node(id='4', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Dcalc/G Cm-3', type='Data'), target=Node(id='1.336', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Dcalc/G Cm-3', type='Data'), target=Node(id='1.034', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Dcalc/G Cm-3', type='Data'), target=Node(id='1.372', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Dcalc/G Cm-3', type='Data'), target=Node(id='1.562', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Absorbtion Coefficient/Mm-1', type='Data'), target=Node(id='1.103', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Absorbtion Coefficient/Mm-1', type='Data'), target=Node(id='1.054', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Absorbtion Coefficient/Mm-1', type='Data'), target=Node(id='1.080', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Absorbtion Coefficient/Mm-1', type='Data'), target=Node(id='1.672', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='F(000)', type='Data'), target=Node(id='3848', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='F(000)', type='Data'), target=Node(id='3008', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='F(000)', type='Data'), target=Node(id='4016', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='F(000)', type='Data'), target=Node(id='4544', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Q For Data Collection/◦', type='Data'), target=Node(id='1.79–26.39', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Q For Data Collection/◦', type='Data'), target=Node(id='2.11–30,54', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Q For Data Collection/◦', type='Data'), target=Node(id='2.06–30.52', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Q For Data Collection/◦', type='Data'), target=Node(id='2.12–27.53', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Limiting Indices', type='Data'), target=Node(id='-15 £ H £ 8, -38 £ K £ 38, -30 £ L £ 30', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Limiting Indices', type='Data'), target=Node(id='-31 £ H £ 18, -40 £ K £ 40, -15 £ L £ 15', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Reflns Collected/Unique', type='Data'), target=Node(id='57408/18509', type='Data'), type='HAS_VALUE'), Relationship(source=Node(id='Reflns Collected/Unique', type='Data'), target=Node(id='61839/25216', type='Data'), type='HAS_VALUE'), Relationship(sou ...
#  GraphDocument(nodes=[Node(id='Goodness-Of-Fit On F2', type='Parameter'), Node(id='Absolute Structure Parameter', type='Parameter'), Node(id='Final R Indices [I > 2S(I)]', type='Parameter'), Node(id='Wr2', type='Parameter'), Node(id='R Indices (All Data)', type='Parameter'), Node(id='Largest Diff. Peak And Hole/E A˚ -3', type='Parameter'), Node(id='-35 £ H £ 31, -44 £ K £ 40, -16 £ L £ 17', type='Parameter')], relationships=[Relationship(source=Node(id='Goodness-Of-Fit On F2', type='Parameter'), target=Node(id='1.104', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Goodness-Of-Fit On F2', type='Parameter'), target=Node(id='1.097', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Goodness-Of-Fit On F2', type='Parameter'), target=Node(id='1.037', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Goodness-Of-Fit On F2', type='Parameter'), target=Node(id='1.023', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Absolute Structure Parameter', type='Parameter'), target=Node(id='0.472(8)', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Absolute Structure Parameter', type='Parameter'), target=Node(id='0.488(7)', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Final R Indices [I > 2S(I)]', type='Parameter'), target=Node(id='R1 = 0.1079', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Final R Indices [I > 2S(I)]', type='Parameter'), target=Node(id='R1 = 0.0374', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Final R Indices [I > 2S(I)]', type='Parameter'), target=Node(id='R1 = 0.0367', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Final R Indices [I > 2S(I)]', type='Parameter'), target=Node(id='R1 = 0.0349', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Wr2', type='Parameter'), target=Node(id='Wr2 = 0.2833', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Wr2', type='Parameter'), target=Node(id='Wr2 = 0.1271', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Wr2', type='Parameter'), target=Node(id='Wr2 = 0.0879', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Wr2', type='Parameter'), target=Node(id='Wr2 = 0.0672', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='R Indices (All Data)', type='Parameter'), target=Node(id='R1 = 0.1451', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='R Indices (All Data)', type='Parameter'), target=Node(id='R1 = 0.0423', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='R Indices (All Data)', type='Parameter'), target=Node(id='R1 = 0.0492', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='R Indices (All Data)', type='Parameter'), target=Node(id='R1 = 0.0482', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Wr2', type='Parameter'), target=Node(id='Wr2 = 0.2973', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Wr2', type='Parameter'), target=Node(id='Wr2 = 0.1311', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Wr2', type='Parameter'), target=Node(id='Wr2 = 0.0916', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Wr2', type='Parameter'), target=Node(id='Wr2 = 0.0706', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Largest Diff. Peak And Hole/E A˚ -3', type='Parameter'), target=Node(id='1.704/-0.950', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Largest Diff. Peak And Hole/E A˚ -3', type='Parameter'), target=Node(id='1.230/-0.406', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Largest Diff. Peak And Hole/E A˚ -3', type='Parameter'), target=Node(id='0.980/-0.795', type='Parameter'), type='HAS_VALUE'), Relationship(source=Node(id='Largest Diff. Peak And Hole/E A˚ -3', type='Parameter'), target=Node(id='0.811/-0.850', type='Parameter'), type='HAS_VALUE'), Rel ...
#  GraphDocument(nodes=[Node(id='C63H55N9O17Zn4', type='Chemical compound'), Node(id='C99H91N9O17Zn4', type='Chemical compound'), Node(id='C103H95N9O17Zn4Fe4', type='Chemical compound'), Node(id='Benzene', type='Chemical compound'), Node(id='Ferrocene', type='Chemical compound')], relationships=[Relationship(source=Node(id='C63H55N9O17Zn4', type='Chemical compound'), target=Node(id='Benzene', type='Chemical compound'), type='DISSOLVED_IN'), Relationship(source=Node(id='C99H91N9O17Zn4', type='Chemical compound'), target=Node(id='Benzene', type='Chemical compound'), type='DISSOLVED_IN'), Relationship(source=Node(id='C103H95N9O17Zn4Fe4', type='Chemical compound'), target=Node(id='Ferrocene', type='Chemical compound'), type='MIXED_WITH')], source=Document(page_content='![7_image_0.png](7_image_0.png)\n\nand then heated under dynamic vacuum at 65 ◦C for 24 h. Anal:\nCalc. for C63H55N9O17Zn4 (%): C 51.4; H 3.8; N 8.6. Found (%): C\n51,7; H 3,8; N 8,7.\n\n[Zn4(dmf)(ur)2(ndc)4]·6C6H6 **(3).** The crystals of 2 (0.100 g, 0.068 mmol) were immersed in benzene (10 ml) for 72 h. After that, colorless crystals of 3 was separated by filtration, and dried on air. Anal: Calc. for C99H91N9O17Zn4 (%): C 61.3; H 4.7; N 6.5.\n\nFound (%): C 60.9; H 4.4; N 6.7.\n\n[Zn4(dmf)(ur)2(ndc)4]·4Fe(C5H5)2 **(4).** A mixture of crystals of 2 (0.050 g, 0.034 mmol), and ferrocene (0.025 g, 0.136 mmol) was heated in evacuated sealed glass tube at 100 ◦C for 10 h. After slow cooling to room temperature, yellow crystals of 4 were separated from excess of ferrocene crystallized on the inner side wall of glass tube. Anal: Calc. for C103H95N9O17Zn4Fe4 (%): C 55.8; H 4.3; N\n5.7. Found (%): C 55.7; H 4.4; N 5.7.\n\n## Gas Sorption Measurements')),
#  GraphDocument(nodes=[Node(id='Dichloromethylene-Exchanged Sample 1', type='Sample'), Node(id='Autosorb-6B-Kr', type='Instrument'), Node(id='Quantachrome', type='Company'), Node(id='Mof', type='Material'), Node(id='Nldft', type='Method'), Node(id='Belsorp-Max', type='Instrument'), Node(id='Clausius–Clapeyron Equation', type='Equation'), Node(id='Bruker–Nonius X8Apex Ccd', type='Instrument'), Node(id='Mo-Ka Radiation', type='Radiation'), Node(id='Sadabs 12', type='Software')], relationships=[Relationship(source=Node(id='Dichloromethylene-Exchanged Sample 1', type='Sample'), target=Node(id='Mof', type='Material'), type='IS_A'), Relationship(source=Node(id='Dichloromethylene-Exchanged Sample 1', type='Sample'), target=Node(id='Autosorb-6B-Kr', type='Instrument'), type='USED_FOR'), Relationship(source=Node(id='Autosorb-6B-Kr', type='Instrument'), target=Node(id='Quantachrome', type='Company'), type='MANUFACTURED_BY'), Relationship(source=Node(id='Mof', type='Material'), target=Node(id='Nldft', type='Method'), type='ANALYZED_BY'), Relationship(source=Node(id='Belsorp-Max', type='Instrument'), target=Node(id='Mof', type='Material'), type='USED_FOR'), Relationship(source=Node(id='Clausius–Clapeyron Equation', type='Equation'), target=Node(id='Mof', type='Material'), type='USED_FOR'), Relationship(source=Node(id='Bruker–Nonius X8Apex Ccd', type='Instrument'), target=Node(id='Dichloromethylene-Exchanged Sample 1', type='Sample'), type='USED_FOR'), Relationship(source=Node(id='Bruker–Nonius X8Apex Ccd', type='Instrument'), target=Node(id='Mo-Ka Radiation', type='Radiation'), type='USED_WITH'), Relationship(source=Node(id='Sadabs 12', type='Software'), target=Node(id='Bruker–Nonius X8Apex Ccd', type='Instrument'), type='USED_WITH')], source=Document(page_content='The dichloromethylene-exchanged sample 1 was activated in vacuum at 100 ◦C for 14 h. Nitrogen adsorption at 77 K was studied by means of Autosorb-6B-Kr (Quantachrome) instrument. Prior to experiment the MOF was degassed under dynamic vacuum (30 mTorr) at 80 ◦C overnight. Adsorption isotherm was measured in a range of 10-5 < P/P0 < 0.995. Pore volume-size distribution was calculated using standard regularization procedure with kernel functions, calculated using NLDFT for silica cylindrical pores. Despite on obvious model restrictions, the calculated isotherm fitted well the experimental one, and the characteristic sizes from pore volume-size distributions correlate with the sizes from X-ray diffraction data. The hydrogen sorption isotherms were measured on BELSORP-max instrument using high-purity gas (99.9999%)\nin the range 0.0–1.0 bar at 77 K (liq. N2 bath) and 87 K (liq. Ar bath). Enthalpies of H2 adsorption were calculated using a variant of the Clausius–Clapeyron equation: ln(P1/P2) = DHads(T2 - T1)/(RT1T2), where Pn - pressure for isotherm n, Tn - temperature for isotherm n, R = 8.3145 J/(mol K). Pressure as a function of the amount adsorbed was determined using the Langmuir–Freundlich fit for each isotherm (see ESI† for details).11\n\n## X-Ray Crystallography\n\nSingle-crystal XRD data collections of 1–4 were performed by using an automated four circle Bruker–Nonius X8Apex CCD\ndiffractometer with Mo-Ka radiation (l = 0.71073 A˚ ). An absorbtion correction was applied based on the intensities of equivalent reflections with the use of the SADABS 12 program.')),
#  GraphDocument(nodes=[Node(id='Shelx-97', type='Program'), Node(id='2,6-Naphtalenedicarboxylate', type='Ligand'), Node(id='Urotropine', type='Ligand'), Node(id='Benzene', type='Molecule'), Node(id='Ferrocene', type='Molecule'), Node(id='Dmf', type='Molecule'), Node(id='Disordered Guest Water Molecules', type='Molecule'), Node(id='1', type='Crystal'), Node(id='2', type='Crystal'), Node(id='4', type='Crystal')], relationships=[Relationship(source=Node(id='1', type='Crystal'), target=Node(id='Shelx-97', type='Program'), type='USED'), Relationship(source=Node(id='2,6-Naphtalenedicarboxylate', type='Ligand'), target=Node(id='1', type='Crystal'), type='PART_OF'), Relationship(source=Node(id='Urotropine', type='Ligand'), target=Node(id='1', type='Crystal'), type='PART_OF'), Relationship(source=Node(id='Benzene', type='Molecule'), target=Node(id='1', type='Crystal'), type='PART_OF'), Relationship(source=Node(id='Ferrocene', type='Molecule'), target=Node(id='1', type='Crystal'), type='PART_OF'), Relationship(source=Node(id='Dmf', type='Molecule'), target=Node(id='1', type='Crystal'), type='PART_OF'), Relationship(source=Node(id='Disordered Guest Water Molecules', type='Molecule'), target=Node(id='1', type='Crystal'), type='PART_OF'), Relationship(source=Node(id='2', type='Crystal'), target=Node(id='1', type='Crystal'), type='RELATED'), Relationship(source=Node(id='4', type='Crystal'), target=Node(id='1', type='Crystal'), type='RELATED')], source=Document(page_content='The structures were solved by direct method and refined on F2 by full-matrix least-squares method in the anisotropic approximation (for non-hydrogen atoms) using SHELX-97 program package.13 Positions of the hydrogen atoms of 2,6-naphtalenedicarboxylate, and urotropine ligands, guest benzene, ferrocene and DMF\nmolecules were calculated geometrically and refined by the rigid model. The hydrogen atoms of disordered guest water molecules in 1 were not located. In the case of 2 and 4 a racemic merohedral twinning was found with the twinning law of {-1, 0, 0; 0, -1, 0; 0, 0, -1} with relative component weights of 0.528(8)/0.472(8) for 2, and 0.512(7)/0.488(7) for 4. X-ray data collections have been performed for several crystals of 1. The data given for 1 in the paper are the best we could achieve. Apparently, lower quality of X-ray data of 1 is due to non-ideal crystal quality and disordering in guest subsystem. A summary of the crystallographic data and structural determination for 1–4 is provided in Table 1. Selected bond length and angles are listed in Tables S1–S4 (see ESI†).'))]

# %% [markdown]
# Now, lets try providing a prompt into the LLM Graph Transformer.
#
# - This prompt will overwrite the default prompt from langchain, therefore, it is probably not a great idea to do this unless we completely mimick the langchain prompt
# - Instead, maybe altering the langchain LLMGraphTransformer class, and add a section for providing additional context in the prompt, is a better idea

# %%
from langchain_core.prompts import ChatPromptTemplate

template = ChatPromptTemplate([
    ("system", "You are creating a knowledge graph from various literature articles. These articles are about Metal-Organic Frameworks (MOFs). "
    "Identify the nodes and relationships found in the article. "
    "For example, if the text states: 'The chemical formula of MOF-5 is [Zn₄O(BDC)₃]', then you should identify "
    "MOF-5 as a 'Metal-Organic Framework' node, Zn as a 'Metal' node, and '(BDC)₃' as a 'Linker' node. "
    "You should also identify the relationships between these nodes, such as: MOF-5 'Has_Linker' with '(BDC)₃'.")
])

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(temperature=0, model_name="gpt-4o-mini")
llm_transformer = LLMGraphTransformer(
  llm=llm, 
  #prompt = template,
  allowed_nodes=["MOF", "Bond", "Atom", "Metal", "Linker"],
  allowed_relationships=["Has_Bond", "Has_Atom", "Has_Linker"],
  #node_properties=["description"], I dont think we need node properties. And "Description" is probably too vague
  #relationship_properties=["description"]
)

# %%
# Process each chunk using the process_text function
graph_documents = []
for chunk in chunks:
    graph_document = process_document(chunk)
    graph_documents.extend(graph_document)

# Print or handle the processed graph_documents as needed
print(f"Processed {len(graph_documents)} GraphDocuments.")
# Out:
# Processed 20 GraphDocuments.

# %%
graph_documents
# Out:
# [GraphDocument(nodes=[Node(id='Dalton Transactions', type='Mof'), Node(id='New Talent Asia', type='Mof'), Node(id='Tohoku University', type='Mof')], relationships=[Relationship(source=Node(id='Dalton Transactions', type='Mof'), target=Node(id='New Talent Asia', type='Mof'), type='HAS_BOND')], source=Document(page_content='This article is published as part of the *Dalton Transactions* **themed issue entitled:** \n\n# New Talent Asia\n\nHighlighting the excellent work being carried out by younger members of the inorganic academic community in Asia Guest Editor Masahiro Yamashita Tohoku University, Japan Published in issue 10, 2011 of *Dalton Transactions*\n\n![0_image_0.png](0_image_0.png)\n\nImage reproduced with permission of Kenneth Kam-Wing Lo Articles in the issue include: PERSPECTIVES: Pyrazolin-4-ylidenes: a new class of intriguing ligands Yuan Han and Han Vinh Huynh, *Dalton Trans*., 2011, DOI: 10.1039/C0DT01037E Solvent induced molecular magnetic changes observed in single-crystal-to-single-crystal transformation Zheng-Ming Hao and Xian-Ming Zhang, *Dalton Trans*., 2011, DOI: 10.1039/C0DT00979B, ARTICLES: \nNegative thermal expansion emerging upon structural phase transition in ZrV2O7 and HfV2O7 Yasuhisa Yamamura, Aruto Horikoshi, Syuma Yasuzuka, Hideki Saitoh and Kazuya Saito Dalton Trans., 2011, DOI: 10.1039/C0DT01087A \nPreparation of surface molecularly imprinted Ru-complex catalysts for asymmetric transfer hydrogenation in water media Zhihuan Weng, Satoshi Muratsugu, Nozomu Ishiguro, Shin-ichi Ohkoshi and Mizuki Tada Dalton Trans., 2011, DOI: 10.1039/C0DT00950D \nVisit the *Dalton Transactions* website for more cutting-edge inorganic and organometallic research www.rsc.org/dalton\n\n# Microporous Sensor: Gas Sorption, Guest Exchange And Guest-Dependant Luminescence Of Metal–Organic Framework†')),
#  GraphDocument(nodes=[Node(id='Zn(Ii)-Containing Metal–Organic Framework', type='Mof'), Node(id='Ndc2-', type='Linker'), Node(id='Ur', type='Linker'), Node(id='Dmf', type='Linker')], relationships=[Relationship(source=Node(id='Zn(Ii)-Containing Metal–Organic Framework', type='Mof'), target=Node(id='Ndc2-', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn(Ii)-Containing Metal–Organic Framework', type='Mof'), target=Node(id='Ur', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn(Ii)-Containing Metal–Organic Framework', type='Mof'), target=Node(id='Dmf', type='Linker'), type='HAS_LINKER')], source=Document(page_content='Sergey A. Sapchenko,a Denis G. Samsonenko,*a,b Danil N. Dybtsev,a,c Maxim S. Melgunovd and Vladimir P. Fedina,b Received 12th August 2010, Accepted 14th October 2010 DOI: 10.1039/c0dt00999g Zn(II)-containing metal–organic framework (MOF) [Zn4(dmf)(ur)2(ndc)4] (ndc2- =\n2,6-naphtalenedicarboxylate, ur = urotropin, dmf = N,N¢-dimethylformamide) was synthesized and characterized by X-ray crystallography and gas sorption analysis. Host MOF retains its crystallinity after guest removal and exchange. Single-crystal to single-crystal formation of different host–guest systems with benzene and ferrocene was investigated. Interesting guest-depended luminescence properties of the porous host framework were observed.\n\n## Introduction')),
#  GraphDocument(nodes=[Node(id='Metal–Organic Coordination Polymers', type='Mof'), Node(id='Metal Ions', type='Metal'), Node(id='Organic Bridging Ligands', type='Linker'), Node(id='Guest Composition', type='Atom'), Node(id='Porous Metal–Organic Frameworks', type='Mof'), Node(id='Functional Guest Species', type='Atom'), Node(id='Porous Coordination Polymers', type='Mof'), Node(id='Host–Guest Complexes', type='Mof'), Node(id='Guest Molecule', type='Atom')], relationships=[Relationship(source=Node(id='Metal–Organic Coordination Polymers', type='Mof'), target=Node(id='Metal Ions', type='Metal'), type='HAS_ATOM'), Relationship(source=Node(id='Metal–Organic Coordination Polymers', type='Mof'), target=Node(id='Organic Bridging Ligands', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Porous Metal–Organic Frameworks', type='Mof'), target=Node(id='Guest Composition', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Porous Metal–Organic Frameworks', type='Mof'), target=Node(id='Functional Guest Species', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Porous Coordination Polymers', type='Mof'), target=Node(id='Guest Molecule', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Host–Guest Complexes', type='Mof'), target=Node(id='Guest Molecule', type='Atom'), type='HAS_ATOM')], source=Document(page_content='Metal–organic coordination polymers constructed from metal ions and organic bridging ligands have attracted considerable attention in recent years.1 The wide variety of organic ligands and practically infinite number of ways to unite metal coordination complexes into extended metal–organic framework lead to a vast number of novel compounds with unique sorption, catalytic activity, luminescence, magnetism.2,3 While gas sorption or catalytic activity of metal–organic frameworks mainly depends on the structure, some other properties, *e.g.* luminescence, depend also on the guest composition, which could be directly applied for chemical sensing. Therefore the synthesis of porous metal–organic frameworks, which are capable of switching their functional characteristics upon guest-related transitions, is an important but challenging task. Other than luminescence itself, such sensor materials should feature at least two essential properties. Firstly, the size of porous channels must be sufficient for accommodation of functional guest species. Secondly, the metal–organic framework should be robust enough to maintain its porosity during the guest removal or exchange. Only several examples of porous coordination polymers with luminescence-based sensing of various guest molecules have been reported to date,4 therefore this highly promising area mainly remains underdeveloped. A\nparticularly important issue here is an unambiguous structural characterization of such host–guest complexes because it allows detailed investigation of interactions between guest molecule and porous framework as well as elucidates the sensing mechanism.')),
#  GraphDocument(nodes=[Node(id='Zn4(Dmf)(Ur)2(Ndc)4·5Dmf·H2O', type='Mof'), Node(id='Zn(No3)2·6H2O', type='Metal'), Node(id='2,6-Naphtalenedicarboxylic Acid', type='Linker'), Node(id='Urotropin', type='Linker'), Node(id='Benzene', type='Atom'), Node(id='Ferrocene', type='Atom')], relationships=[Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4·5Dmf·H2O', type='Mof'), target=Node(id='Zn(No3)2·6H2O', type='Metal'), type='HAS_BOND'), Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4·5Dmf·H2O', type='Mof'), target=Node(id='2,6-Naphtalenedicarboxylic Acid', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4·5Dmf·H2O', type='Mof'), target=Node(id='Urotropin', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4·5Dmf·H2O', type='Mof'), target=Node(id='Benzene', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4·5Dmf·H2O', type='Mof'), target=Node(id='Ferrocene', type='Atom'), type='HAS_ATOM')], source=Document(page_content="Single-crystal X-ray diffraction technique is often limited here, because of guest disorder problem or fragility of metal-organic single crystals during the guest exchange.5 In this work we describe the synthesis and characterization of a novel porous metal–organic coordination polymer\n[Zn4(dmf)(ur)2(ndc)4]·5DMF·H2O (1), which meets the abovementioned requirements for potential sensor applications. The solvent molecules can be removed from this MOF without loss of the sample's crystallinity. The resulting permanently porous framework demonstrates a reversible gas sorption as well as an uptake of various guests. The corresponding guest-free and guest-exchanged samples were characterized by a single-crystal X-ray diffraction analysis. Most interestingly, the luminescent properties of open framework [Zn4(dmf)(ur)2(ndc)4] are highly depended on the guest molecules, accommodated in the pores. The benzene molecules enhance the framework luminescence, while ferrocene effectively quenches it. Such pronounced guestdepended response could be applied for sensing of organic or organometallic molecules, many of which are very dangerous both to Nature and to human health.\n\n## Results And Discussion\n\nCompound 1 was obtained by heating a mixture of Zn(NO3)2·6H2O, 2,6-naphtalenedicarboxylic acid (H2ndc) and urotropin (ur) in DMF at 100 ◦C for 10 h. Compound 1 crystallizes in the monoclinic system with the space group P21/n. Asymmetric unit of 1 comprises four crystallographically independent zinc atoms forming two different binuclear carboxylate complexes as secondary building units (Fig. 1). In the first building unit (type A) the tetragonal-pyramidal Zn(1) and Zn(2) centers are similar.")),
#  GraphDocument(nodes=[Node(id='Zn2(Coo)4', type='Metal'), Node(id='Ndc2-', type='Linker'), Node(id='Urotropin', type='Linker'), Node(id='M2-Rcoo-O,O¢', type='Linker'), Node(id='Zn(3)', type='Metal'), Node(id='Zn(4)', type='Metal'), Node(id='Dmf', type='Linker')], relationships=[Relationship(source=Node(id='Zn2(Coo)4', type='Metal'), target=Node(id='Ndc2-', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn2(Coo)4', type='Metal'), target=Node(id='Urotropin', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn(3)', type='Metal'), target=Node(id='Ndc2-', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn(3)', type='Metal'), target=Node(id='Urotropin', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn(4)', type='Metal'), target=Node(id='Ndc2-', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn(4)', type='Metal'), target=Node(id='Urotropin', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn(4)', type='Metal'), target=Node(id='Dmf', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn(3)', type='Metal'), target=Node(id='Zn(4)', type='Metal'), type='HAS_BOND')], source=Document(page_content='Each metal cation is coordinated by four O atoms of four ndc2- and one N atom of urotropin, such as these cations are interconnected via four bridging bidentate m2-RCOO-O,O¢ groups. This binuclear carboxylate complex {Zn2(COO)4}, known as "paddle-wheel",\nis very typical and common in metal carboxylate coordination structures. The Zn–O (2.006(5)–2.069(6) A˚ ) and Zn–N (2.065(6), 2.067(6) A˚ ) bond lengths found fall within the common values for Zn(II) complexes with coordination number 5. The structure of the second carboxylate secondary building unit (type B), to our best\n\n![2_image_0.png](2_image_0.png)\n\nknowledge, has never been described before and unprecedented in coordination frameworks. Contrary to the binuclear complex A, the coordination environments of Zn(3) and Zn(4) cations in B are different (Fig. 1). The distorted tetrahedral Zn(3) center is coordinated by three O atoms of three ndc2- ligands and one N atom of urotropin. The Zn(3)–O (1,899(9)–1,962(7) A˚ ) and Zn(3)–N(12) (2.111(7) A˚ ) bond lengths found fall within the common values for tetrahedral Zn(II) complexes. The distorted octahedral geometry of Zn(4) cation is composed of five O atoms of two monodentate ndc2-, one chelating bidentate ndc2- ligands and one coordinated dmf molecule, as well as one N atom of urotropin ligand. The Zn(4)–N(22) bond length is 2.143(7) A˚ .')),
#  GraphDocument(nodes=[], relationships=[], source=Document(page_content='There are two type of Zn(4)–O distances. The first one includes two bonds with bridging ndc2- ligands (1.982(7), 1.997(6) A˚ )\nand one of two bonds with bidentate ndc2- ligand (2.161(16)\nA˚ ). The residual bond with bidentate ndc2- ligand and bond with dmf molecule form the second type. Thereby, coordination number of Zn(4) atom can be assigned as 4 + 2. In the type B\nbuilding unit two metal cations Zn(3) and Zn(4) are interlinked via two bridging m2-RCOO-O,O¢ groups, so the overall formula of the coordination complex is {Zn2(dmf)(COO)4}. The metal–\nligand distances in both carboxylate binuclear complexes lie within typical corresponding ranges with some acceptable deviations, indicating apparent distortion.\n\nIn the structure 1 the organic ligands act as ditopic connectors between the binuclear secondary building units. Therefore, both binuclear complexes A and B could be simplified as six-connected nodes, each with distorted 4 + 2 octahedral geometry of four linear ndc2- and two angular urotropin linkers. The main difference is that urotropins are located in *trans*-positions in type A but in cis-positions in the type B node (Fig. 1). The ndc2- bridges connect nodes A and A, B and B, as well as A and B. At the same time urotropin ligands link only nodes A and B. Each type A node is connected through ndc2- to two nodes A and two nodes B\nand through urotropin to two nodes B. Similarly, each B node is connected through ndc2- to two nodes A and two B and through urotropin to two nodes A. The overall three-dimensional (3D)\ntopology of the binodal 6-connected net in the metal–organic framework 1 is very complicated (Fig. S1†), one may refer to its point symbol (3244.68.8)(3.44.53.66.8).')),
#  GraphDocument(nodes=[Node(id='1', type='Mof'), Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), Node(id='Ndc2-', type='Linker'), Node(id='Urotropin', type='Linker')], relationships=[Relationship(source=Node(id='1', type='Mof'), target=Node(id='Ndc2-', type='Linker'), type='HAS_ATOM'), Relationship(source=Node(id='1', type='Mof'), target=Node(id='Urotropin', type='Linker'), type='HAS_ATOM')], source=Document(page_content='The interstitial space between inorganic carboxylate complexes and organic ligands in as-synthesized 1 is occupied by solvent guest molecules. The single-crystal X-ray diffraction analysis revealed five DMF and one H2O molecules per asymmetric unit of 1. The formula [Zn4(dmf)(ur)2(ndc)4]·5DMF·H2O was independently confirmed by elemental and thermogravimetrical\n(TG) analyses. The phase purity of 1 was also proved by powder X-ray diffraction method (See SI for the details). In particular, the TG analysis on the as-synthesized 1 indicated a gradual weight loss of 21% in the temperature range 25–300 ◦C, which is consistent with evacuation of one H2O and 5 DMF molecules. The following decrease of mass can be associated with the destruction of the metal–organic framework (Fig. S2). The guest molecules occupy distorted hexagonal channels with characteristic dimensions 9.5\n¥ 11 A˚ 2, running along a axis of 3D framework (Fig. 2). A space within channels is occupied by DMF and disordered H2O guest molecules, which form a weak H-bonding with CH or CH2 groups of ndc2- or urotropin ligands respectively, as well as with each\n\n![3_image_1.png](3_image_1.png)')),
#  GraphDocument(nodes=[Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), Node(id='Dmf', type='Linker'), Node(id='Ch2Cl2', type='Linker'), Node(id='P21/N', type='Mof'), Node(id='Cc', type='Mof'), Node(id='Platon 6', type='Linker'), Node(id='N2', type='Atom')], relationships=[Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), target=Node(id='Dmf', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), target=Node(id='Ch2Cl2', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), target=Node(id='P21/N', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), target=Node(id='Cc', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), target=Node(id='Platon 6', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), target=Node(id='N2', type='Atom'), type='HAS_ATOM')], source=Document(page_content='To prepare guest-free framework [Zn4(dmf)(ur)2(ndc)4] (2) the DMF molecules was exchanged with readily volatile CH2Cl2 solvent, followed by slight heating in the dynamic vacuum. A structure of guest-free compound 2 is generally similar to 1, but there are some distinct differences. Whereas the compound 1 crystallizes in *P21/n* space group, compound 2 has slightly higher Cc symmetry. Such difference does not affect significantly Zn– O and Zn–N interatomic distances. The channels running along c axis in 2 adopt more symmetric shape than in 1 and have characteristic dimensions 10.5 ¥ 10.5 A˚ (Fig. 3). The free solvent accessible volume in 2, derived from PLATON 6 routine analysis\n(filling of the cavities with probe spheres of radius 1.2 A˚ ) was found to be 43%. Interestingly, framework 2 is not centrosymmetric\n(sp. group Cc has no inversion center) that leads to racemic merohedral twinning of the crystals 2 contrary to 1. Attempts to apply centrosymmetric space group C2/c during the refinement of 2 leads to disorder of coordinated dmf molecules over two symmetrically related positions. In case of non centrosymmetric group Cc, the disordering is not observed.\n\nThe high stability of the guest-free metal–organic framework was further confirmed by N2 sorption isotherm at 77 K for 2\n(Fig. 4), which shows type I behavior with small hysteresis and\n\n![3_image_0.png](3_image_0.png)\n\n![3_image_2.png](3_image_2.png)')),
#  GraphDocument(nodes=[Node(id='Bulk Sample', type='Mof'), Node(id='Brunauer–Emmett–Teller (Bet) Surface Area', type='Atom'), Node(id='Channels Volume-Size Distribution', type='Atom'), Node(id='X-Ray Analysis', type='Atom'), Node(id='Pores', type='Atom'), Node(id='H2 Uptake', type='Atom'), Node(id='Density Of H2 In Pores', type='Atom'), Node(id='Density Of Liquid H2', type='Atom'), Node(id='Storage Density Of Hydrogen', type='Atom'), Node(id='Hydrogen Isotherm', type='Atom'), Node(id='Enthalpy Of Adsorption', type='Atom'), Node(id='D*Hads*', type='Atom'), Node(id='Microporous Framework 2', type='Mof'), Node(id='Single Crystals Of Inclusion Compound [Zn4(Dmf)(Ur)2(Ndc)4]·6C6H6 (3)', type='Mof'), Node(id='Framework Structure Of Benzene Adduct 3', type='Mof'), Node(id='Guest Molecules', type='Atom'), Node(id='Framework Symmetry', type='Atom'), Node(id='Space Group', type='Atom')], relationships=[Relationship(source=Node(id='Bulk Sample', type='Mof'), target=Node(id='Brunauer–Emmett–Teller (Bet) Surface Area', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Bulk Sample', type='Mof'), target=Node(id='Channels Volume-Size Distribution', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Channels Volume-Size Distribution', type='Atom'), target=Node(id='X-Ray Analysis', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Bulk Sample', type='Mof'), target=Node(id='Pores', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Pores', type='Atom'), target=Node(id='H2 Uptake', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Pores', type='Atom'), target=Node(id='Density Of H2 In Pores', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Liquid H2', type='Atom'), target=Node(id='Density Of Liquid H2', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Bulk Sample', type='Mof'), target=Node(id='Storage Density Of Hydrogen', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Bulk Sample', type='Mof'), target=Node(id='Hydrogen Isotherm', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Hydrogen Isotherm', type='Atom'), target=Node(id='Enthalpy Of Adsorption', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Microporous Framework 2', type='Mof'), target=Node(id='D*Hads*', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Microporous Framework 2', type='Mof'), target=Node(id='Single Crystals Of Inclusion Compound [Zn4(Dmf)(Ur)2(Ndc)4]·6C6H6 (3)', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Single Crystals Of Inclusion Compound [Zn4(Dmf)(Ur)2(Ndc)4]·6C6H6 (3)', type='Mof'), target=Node(id='Framework Structure Of Benzene Adduct 3', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Single Crystals Of Inclusion Compound [Zn4(Dmf)(Ur)2(Ndc)4]·6C6H6 (3)', type='Mof'), target=Node(id='Guest Molecules', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Guest Molecules', type='Atom'), target=Node(id='Framework Symmetry', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Framework Symmetry', type='Atom'), target=Node(id='Space Group', type='Atom'), type='HAS_ATOM')], source=Document(page_content='thus ensuring permanent microporosity of the bulk sample. The formally calculated Brunauer–Emmett–Teller (BET) surface area is 820 m2 g-1. Channels volume-size distribution diagram (Fig. S3†)\nshows the only intense peak at 0.9 nm and agrees quantitatively with the result of X-ray analysis. The volume of these pores was calculated to be 0.2 cm3 g-1. The maximum H2 uptake for 2 at 1 atm and 77 K is 0.92 wt.% H2 (Fig. 5). Knowing pore volume, one can estimate the density of H2 in pores as 0.04 g cm-3. For comparison, density of liquid H2 at 14 K is 0.07 g cm-3. The storage density of hydrogen in the bulk sample at 1 bar is 0.009 g cm-3, which is equivalent to the density of H2 at 2.7 MPa (estimated according\n\n![4_image_0.png](4_image_0.png)\n\nto ideal gas equation) at 77 K. Additional hydrogen isother ...
#  GraphDocument(nodes=[Node(id='Benzene', type='Atom'), Node(id='Ndc2- Ligand', type='Linker'), Node(id='Ferrocene', type='Atom'), Node(id='Zn(4)', type='Metal'), Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·4Fe(C5H5)2 (4)', type='Mof'), Node(id='Structure 4', type='Mof'), Node(id='Structure 1–3', type='Mof')], relationships=[Relationship(source=Node(id='Benzene', type='Atom'), target=Node(id='Ndc2- Ligand', type='Linker'), type='HAS_BOND'), Relationship(source=Node(id='Ferrocene', type='Atom'), target=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·4Fe(C5H5)2 (4)', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Zn(4)', type='Metal'), target=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·4Fe(C5H5)2 (4)', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·4Fe(C5H5)2 (4)', type='Mof'), target=Node(id='Structure 4', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Structure 1–3', type='Mof'), target=Node(id='Zn(4)', type='Metal'), type='HAS_ATOM')], source=Document(page_content='There are no strong contacts between guest benzene molecules except for specific C–H ◊◊◊p interactions (Fig. S6†), which are common in such aryl molecules packing.7 We also found some weak H-bonds between CH group of benzene and carboxyl group of ndc2- ligand. The host–guest adduct with ferrocene was prepared by heating a mixture of single crystals of 2 and solid ferrocene in an evacuated sealed glass tube at 100 ◦C for 10 h. After slow cooling to room temperature, yellow crystals of\n[Zn4(dmf)(ur)2(ndc)4]·4Fe(C5H5)2 (4) were separated from excess of the ferrocene. Noteworthy, the corresponding ferrocene adduct cannot be obtained by a reaction of 2 with ferrocene solution in cyclohexane. As identified from the single-crystal X-ray diffraction data, the ferrocene-imbued framework of host–guest system 4 has less distorted monoclinic Cc space group symmetry compared to that in 3 (Fig. 7). The most significant difference in 4 is that the all three ndc2- ligands are coordinated to Zn(4) atom on monodentate manner, whereas in 1–3 one ndc2- ligand is always bidentate. As a result, Zn(4) in structure 4 has distorted trigonal bipyramidal coordination environment in contrast to distorted octahedral one in 1–3 (Fig. S7†). A space within the channels is occupied by ferrocene molecules of four crystallographically independent types. Interestingly, one of them is disordered over two positions with the site occupancy factors being 0.32 and 0.68 (Fig. S8†). Except for van-der-Waals contacts, we could not identify any specific interactions between ferrocene molecules and the framework, as well as between guest molecules. We note here, that the framework stability and phase purity of guest-exchange compounds 3 and 4 were independently confirmed by X-ray powder diffraction method (Fig. S9†).\n\nThe solid-state photoluminescence properties of complexes 1–4 were investigated at room temperature (Fig. 8, Fig. S10†).')),
#  GraphDocument(nodes=[Node(id='Emissions_Spectra', type='Mof'), Node(id='Photoluminescence_Spectra', type='Mof'), Node(id='Materials_1-3', type='Mof'), Node(id='Blue_Emission', type='Mof'), Node(id='Naphtalenedicarboxylate', type='Mof'), Node(id='Ferrocene', type='Mof'), Node(id='Fecp2', type='Mof'), Node(id='Luminescence_Quenching_Mechanisms', type='Mof'), Node(id='Energy_Transfer', type='Mof'), Node(id='Electron_Transfer', type='Mof'), Node(id='Framework_Photoluminescence', type='Mof')], relationships=[Relationship(source=Node(id='Emissions_Spectra', type='Mof'), target=Node(id='Photoluminescence_Spectra', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Photoluminescence_Spectra', type='Mof'), target=Node(id='Materials_1-3', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Materials_1-3', type='Mof'), target=Node(id='Blue_Emission', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Blue_Emission', type='Mof'), target=Node(id='Naphtalenedicarboxylate', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Ferrocene', type='Mof'), target=Node(id='Framework_Photoluminescence', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Luminescence_Quenching_Mechanisms', type='Mof'), target=Node(id='Energy_Transfer', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Luminescence_Quenching_Mechanisms', type='Mof'), target=Node(id='Electron_Transfer', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Energy_Transfer', type='Mof'), target=Node(id='Fecp2', type='Mof'), type='HAS_BOND')], source=Document(page_content='Their emissions spectra were collected from 380 nm to 600 nm with excitation wavelength at l = 370 nm. The positions of maxima of the photoluminescence spectra for the materials 1–3 are the identical. Some deviations in the luminescence intensities for these materials could be attributed to the method errors. All compounds 1–3 exhibit strong blue emission with broad maximum at l = 430 nm which can be assigned to naphtalenedicarboxylate (ndc2-) intraligand emission p–p*. However, the presence of ferrocene in the host–guest compound 4 essentially quenches the photoluminescence of the framework. In fact, the ferrocene molecule and its derivatives have been widely used as a luminescence quenchers,8 particularly, because of their high stability under visible irradiation and capacity to inhibit the lowest energy excited states (generally, the triplet state).9 Such photoluminescence quenching led to numerous applications in the areas of analytical chemistry, molecular organized systems and biology.10 The excitation energy is transferred to the ferrocene FeCp2, followed by the thermal relaxation of the excited FeCp2* state. There are two possible luminescence quenching mechanisms, known as energy transfer and electron transfer.9 The later is unlikely, because it should involve electron transfer from the ferrocene to exited anionic ligand, forming intermediate radical species ndc3-∑, which should be very unstable. The energy transfer mechanism requires the luminescence radiation energy to be higher, than the energy of the first exited state of ferrocene FeCp2*, which is 21800 cm-1. As mentioned above, the emitted radiation wavelength of p–p* transitions in ndc2- has maximum at l = 430 nm (or 23250 cm-1), which is just enough to promote the ferrocene excitation and effectively absorb the framework photoluminescence. Therefore, we believe that observed quenching of the metal–organic framework luminescence by the ferrocene follows the energy transfer mechanisms. The unique')),
#  GraphDocument(nodes=[Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]', type='Mof'), Node(id='Aromatic Compounds', type='Linker'), Node(id='Other Compounds', type='Linker')], relationships=[Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]', type='Mof'), target=Node(id='Aromatic Compounds', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]', type='Mof'), target=Node(id='Other Compounds', type='Linker'), type='HAS_LINKER')], source=Document(page_content='combination of the pronounced guest-dependant photoluminescence, great framework stability and potent sorption capability of microporous metal–organic material [Zn4(dmf)(ur)2(ndc)4] makes is very strong candidate for practical sensing applications for aromatic or other compounds. More experiments are currently under way in order to investigate the relations between host–guest interactions and luminescence properties of such supramolecular compounds.')),
#  GraphDocument(nodes=[Node(id='Zn(Ii) Metal–Organic Framework', type='Mof')], relationships=[], source=Document(page_content='## Conclusions\n\nA novel microporous Zn(II) metal–organic framework with permanent porosity has been synthesized and structurally characterized. It is shown that as-synthesized form of this MOF-material retains its single crystallinity after guest molecules removal or exchange. The permanent porosity was further confirmed by nitrogen and hydrogen sorption data. Additionally, the pronounced guest-depended photoluminescence properties have been demonstrated, which open great possibilities to use this material for practical sensing applications.\n\n## Experimental General Remarks\n\nAll chemicals purchased were of reagent grade and were used as received without further purification. Methylene chloride was purified according to standard procedure. FTIR spectra (KBr pellets) were recorded in the range of 4000–400 cm-1 on a Scimitar FTS 2000 Fourier-transform infrared spectrometer. Powder X-ray diffraction (PXRD) data were collected with Cu-Ka radiation on a Philips PW 1830 instrument equipped with a PW 1820 vertical Bragg–Brentano powder goniometer and a PW 1710 control unit.\n\n![5_image_0.png](5_image_0.png)\n\n![6_image_0.png](6_image_0.png)\n\nThermogravimetric analysis (TGA) was carried out at a ramp rate of 10 ◦C min-1 in a helium atmosphere with a NETZSCH\nTG 209 F1 instrument. Elemental analyses on C, H, and N\nwere performed on a Euro EA 3000 CHN Elemental Analyzer.\n\nFluorescence emission spectra were collected on a Varian Cary Eclipse spectrofluorimeter.\n\n## Synthesis')),
#  GraphDocument(nodes=[Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), Node(id='Zn(No3)2·6H2O', type='Metal'), Node(id='2,6-Naphtalenedicarboxylic Acid', type='Linker'), Node(id='Urotropine', type='Linker'), Node(id='Dmf', type='Linker'), Node(id='Colorless Crystals', type='Mof'), Node(id='Tga Data', type='Bond')], relationships=[Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), target=Node(id='Zn(No3)2·6H2O', type='Metal'), type='HAS_BOND'), Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), target=Node(id='2,6-Naphtalenedicarboxylic Acid', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), target=Node(id='Urotropine', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), target=Node(id='Dmf', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Colorless Crystals', type='Mof'), target=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Tga Data', type='Bond'), target=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), type='HAS_BOND')], source=Document(page_content='[Zn4(dmf)(ur)2(ndc)4]·5DMF·**H2O (1).** A mixture of Zn(NO3)2·6H2O (0.300 g, 1.00 mmol), 2,6-naphtalenedicarboxylic acid (0.216 g, 1.00 mmol), and urotropine (0.070 g, 0.50 mmol)\nin DMF (25 mL) was heated at 100 ◦C for 10 h in teflon-lined capped container under autogenous pressure. After slow cooling to room temperature, colorless crystals of 1 were separated by filtration, washed with DMF, and then diethylether and dried on air. Yield 0.434 g (28%). Anal: Calc. for C78H92N14O23Zn4 (%) C\n50.5; H 5.0; N 10.6. Found (%): C 49.9; H 5.2; N 10.6. IR (KBr, cm-1): 3435 (w), 3060 (w), 2928 (w), 1666 (s), 1616 (m), 1585 (m),\n1496 (w), 1408 (s), 1356 (m), 1251 (w), 1227 (w), 1196 (w), 1096 (w), 1027 (m), 993 (m), 922 (w), 836 (w), 784 (s), 730 (w), 660 (w),\n588 (w), 481 (m). TGA data: calc. weight loss for 5DMF + H2O:\n21%; found: 21%.\n\n[Zn4(dmf)(ur)2(ndc)4] (2). The crystals of 1 (0.100 g, 0.056 mmol) were immersed into dried CH2Cl2 (15 mL) for 72 h,')),
#  GraphDocument(nodes=[Node(id='Compound_1', type='Mof'), Node(id='Compound_2', type='Mof'), Node(id='Compound_3', type='Mof'), Node(id='Compound_4', type='Mof'), Node(id='Empirical_Formula_1', type='Linker'), Node(id='Empirical_Formula_2', type='Linker'), Node(id='Empirical_Formula_3', type='Linker'), Node(id='Empirical_Formula_4', type='Linker'), Node(id='Formula_Weight_1', type='Linker'), Node(id='Formula_Weight_2', type='Linker'), Node(id='Formula_Weight_3', type='Linker'), Node(id='Formula_Weight_4', type='Linker'), Node(id='T_K_1', type='Linker'), Node(id='T_K_2', type='Linker'), Node(id='T_K_3', type='Linker'), Node(id='T_K_4', type='Linker'), Node(id='Crystal_System_1', type='Linker'), Node(id='Crystal_System_2', type='Linker'), Node(id='Crystal_System_3', type='Linker'), Node(id='Crystal_System_4', type='Linker'), Node(id='Space_Group_1', type='Linker'), Node(id='Space_Group_2', type='Linker'), Node(id='Space_Group_3', type='Linker'), Node(id='Space_Group_4', type='Linker'), Node(id='A_A_1', type='Linker'), Node(id='A_A_2', type='Linker'), Node(id='A_A_3', type='Linker'), Node(id='A_A_4', type='Linker'), Node(id='B_A_1', type='Linker'), Node(id='B_A_2', type='Linker'), Node(id='B_A_3', type='Linker'), Node(id='B_A_4', type='Linker'), Node(id='C_A_1', type='Linker'), Node(id='C_A_2', type='Linker'), Node(id='C_A_3', type='Linker'), Node(id='C_A_4', type='Linker')], relationships=[Relationship(source=Node(id='Compound_1', type='Mof'), target=Node(id='Empirical_Formula_1', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_2', type='Mof'), target=Node(id='Empirical_Formula_2', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_3', type='Mof'), target=Node(id='Empirical_Formula_3', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_4', type='Mof'), target=Node(id='Empirical_Formula_4', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_1', type='Mof'), target=Node(id='Formula_Weight_1', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_2', type='Mof'), target=Node(id='Formula_Weight_2', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_3', type='Mof'), target=Node(id='Formula_Weight_3', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_4', type='Mof'), target=Node(id='Formula_Weight_4', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_1', type='Mof'), target=Node(id='T_K_1', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_2', type='Mof'), target=Node(id='T_K_2', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_3', type='Mof'), target=Node(id='T_K_3', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_4', type='Mof'), target=Node(id='T_K_4', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_1', type='Mof'), target=Node(id='Crystal_System_1', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_2', type='Mof'), target=Node(id='Crystal_System_2', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_3', type='Mof'), target=Node(id='Crystal_System_3', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_4', type='Mof'), target=Node(id='Crystal_System_4', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_1', type='Mof'), target=Node(id='Space_Group_1', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_2', type='Mof'), target=Node(id='Space_Group_2', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_3', type='Mof'), target=Node(id='Space_Group_3', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_4', type='Mof'), target=Node(id='Space_Group_4', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Compound_1', type='Mof'), target=Node(id='A_A_1', type='Linker'), type='HAS_LINKER'), ...
#  GraphDocument(nodes=[Node(id='B/◦', type='Mof'), Node(id='Volume/A˚ 3', type='Mof'), Node(id='Z', type='Mof'), Node(id='Dcalc/G Cm-3', type='Mof'), Node(id='Absorbtion Coefficient/Mm-1', type='Mof'), Node(id='F(000)', type='Mof'), Node(id='Crystal Size/Mm', type='Mof'), Node(id='Q For Data Collection/◦', type='Mof'), Node(id='Limiting Indices', type='Mof'), Node(id='Reflns Collected/Unique', type='Mof'), Node(id='Rint', type='Mof')], relationships=[Relationship(source=Node(id='B/◦', type='Mof'), target=Node(id='Volume/A˚ 3', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='B/◦', type='Mof'), target=Node(id='Z', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='B/◦', type='Mof'), target=Node(id='Dcalc/G Cm-3', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='B/◦', type='Mof'), target=Node(id='Absorbtion Coefficient/Mm-1', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='B/◦', type='Mof'), target=Node(id='F(000)', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='B/◦', type='Mof'), target=Node(id='Crystal Size/Mm', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='B/◦', type='Mof'), target=Node(id='Q For Data Collection/◦', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='B/◦', type='Mof'), target=Node(id='Limiting Indices', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='B/◦', type='Mof'), target=Node(id='Reflns Collected/Unique', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='B/◦', type='Mof'), target=Node(id='Rint', type='Mof'), type='HAS_BOND')], source=Document(page_content='| b/◦                                      | 98.232(1)                                       | 97.318(1)                                | 97.023(1)          | 96.306(1)          |\n| Volume/A˚ 3                              | 9221.2(9)                                       | 9456.8(4)                                | 9394.0(3)          | 9422.1(6)          |\n| Z                                        | 4                                               | 4                                        | 4                  | 4                  |\n| Dcalc/g cm-3                             | 1.336                                           | 1.034                                    | 1.372              | 1.562              |\n| Absorbtion coefficient/mm-1              | 1.103                                           | 1.054                                    | 1.080              | 1.672              |\n| F(000)                                   | 3848                                            | 3008                                     | 4016               | 4544               |\n| Crystal size/mm                          | 0.32 ¥ 0.11 ¥ 0.07                              | 0.36 ¥ 0.16 ¥ 0.14                       | 0.20 ¥ 0.18 ¥ 0.12 | 0,09 ¥ 0,08 ¥ 0,06 |\n| q for data collection/◦                  | 1.79–26.39                                      | 2.11–30,54                               | 2.06–30.52         | 2.12–27.53         |\n| Limiting indices                         | -15 £ h £ 8, -38 £ k £ 38, -30 £ l £ 30         | -31 £ h £ 18, -40 £ k £ 40, -15 £ l £ 15 |                    |                    |\n| Reflns collected/unique                  | 57408/18509                                     | 61839/25216                              | 125023/28654       | 36506/17100        |\n| Rint                                     | 0.0555                                          | 0.0171                                   | 0.0279             | 0.0335             |')),
#  GraphDocument(nodes=[Node(id='Goodness-Of-Fit On F2', type='Mof'), Node(id='Absolute Structure Parameter', type='Mof'), Node(id='Final R Indices [I > 2S(I)]', type='Mof'), Node(id='Wr2', type='Mof'), Node(id='R Indices (All Data)', type='Mof'), Node(id='Largest Diff. Peak And Hole/E A˚ -3', type='Mof'), Node(id='-35 £ H £ 31, -44 £ K £ 40, -16 £ L £ 17', type='Mof')], relationships=[Relationship(source=Node(id='Goodness-Of-Fit On F2', type='Mof'), target=Node(id='1.104', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Goodness-Of-Fit On F2', type='Mof'), target=Node(id='1.097', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Goodness-Of-Fit On F2', type='Mof'), target=Node(id='1.037', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Goodness-Of-Fit On F2', type='Mof'), target=Node(id='1.023', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Absolute Structure Parameter', type='Mof'), target=Node(id='0.472(8)', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Absolute Structure Parameter', type='Mof'), target=Node(id='0.488(7)', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Final R Indices [I > 2S(I)]', type='Mof'), target=Node(id='R1 = 0.1079', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Final R Indices [I > 2S(I)]', type='Mof'), target=Node(id='R1 = 0.0374', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Final R Indices [I > 2S(I)]', type='Mof'), target=Node(id='R1 = 0.0367', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Final R Indices [I > 2S(I)]', type='Mof'), target=Node(id='R1 = 0.0349', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Wr2', type='Mof'), target=Node(id='Wr2 = 0.2833', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Wr2', type='Mof'), target=Node(id='Wr2 = 0.1271', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Wr2', type='Mof'), target=Node(id='Wr2 = 0.0879', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Wr2', type='Mof'), target=Node(id='Wr2 = 0.0672', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='R Indices (All Data)', type='Mof'), target=Node(id='R1 = 0.1451', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='R Indices (All Data)', type='Mof'), target=Node(id='R1 = 0.0423', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='R Indices (All Data)', type='Mof'), target=Node(id='R1 = 0.0492', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='R Indices (All Data)', type='Mof'), target=Node(id='R1 = 0.0482', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Wr2', type='Mof'), target=Node(id='Wr2 = 0.2973', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Wr2', type='Mof'), target=Node(id='Wr2 = 0.1311', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Wr2', type='Mof'), target=Node(id='Wr2 = 0.0916', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Wr2', type='Mof'), target=Node(id='Wr2 = 0.0706', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Largest Diff. Peak And Hole/E A˚ -3', type='Mof'), target=Node(id='1.704/-0.950', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Largest Diff. Peak And Hole/E A˚ -3', type='Mof'), target=Node(id='1.230/-0.406', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Largest Diff. Peak And Hole/E A˚ -3', type='Mof'), target=Node(id='0.980/-0.795', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='Largest Diff. Peak And Hole/E A˚ -3', type='Mof'), target=Node(id='0.811/-0.850', type='Mof'), type='HAS_ATOM'), Relationship(source=Node(id='-35 £ H £ 31, -44 £ K £ 40, -16 £ L £ 17', type='Mof'), target=Node(id='-17 £ H £ 17, -44 £ K £ 39, -35 £ L £ 32', type='Mof'), type='HAS_ATOM')], source=Document(page_content='| Goodness-of-fit on F2                    | 1.104                                           | 1.097                                    | 1.037              | 1.023              ...
#  GraphDocument(nodes=[Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·6C6H6', type='Mof'), Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·4Fe(C5H5)2', type='Mof'), Node(id='C63H55N9O17Zn4', type='Mof'), Node(id='C99H91N9O17Zn4', type='Mof'), Node(id='C103H95N9O17Zn4Fe4', type='Mof'), Node(id='Benzene', type='Linker'), Node(id='Ferrocene', type='Linker')], relationships=[Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·6C6H6', type='Mof'), target=Node(id='Benzene', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·4Fe(C5H5)2', type='Mof'), target=Node(id='Ferrocene', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='C63H55N9O17Zn4', type='Mof'), target=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·6C6H6', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='C99H91N9O17Zn4', type='Mof'), target=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·6C6H6', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='C103H95N9O17Zn4Fe4', type='Mof'), target=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·4Fe(C5H5)2', type='Mof'), type='HAS_BOND')], source=Document(page_content='![7_image_0.png](7_image_0.png)\n\nand then heated under dynamic vacuum at 65 ◦C for 24 h. Anal:\nCalc. for C63H55N9O17Zn4 (%): C 51.4; H 3.8; N 8.6. Found (%): C\n51,7; H 3,8; N 8,7.\n\n[Zn4(dmf)(ur)2(ndc)4]·6C6H6 **(3).** The crystals of 2 (0.100 g, 0.068 mmol) were immersed in benzene (10 ml) for 72 h. After that, colorless crystals of 3 was separated by filtration, and dried on air. Anal: Calc. for C99H91N9O17Zn4 (%): C 61.3; H 4.7; N 6.5.\n\nFound (%): C 60.9; H 4.4; N 6.7.\n\n[Zn4(dmf)(ur)2(ndc)4]·4Fe(C5H5)2 **(4).** A mixture of crystals of 2 (0.050 g, 0.034 mmol), and ferrocene (0.025 g, 0.136 mmol) was heated in evacuated sealed glass tube at 100 ◦C for 10 h. After slow cooling to room temperature, yellow crystals of 4 were separated from excess of ferrocene crystallized on the inner side wall of glass tube. Anal: Calc. for C103H95N9O17Zn4Fe4 (%): C 55.8; H 4.3; N\n5.7. Found (%): C 55.7; H 4.4; N 5.7.\n\n## Gas Sorption Measurements')),
#  GraphDocument(nodes=[Node(id='Dichloromethylene-Exchanged Sample 1', type='Mof'), Node(id='Mo-Ka Radiation', type='Bond')], relationships=[], source=Document(page_content='The dichloromethylene-exchanged sample 1 was activated in vacuum at 100 ◦C for 14 h. Nitrogen adsorption at 77 K was studied by means of Autosorb-6B-Kr (Quantachrome) instrument. Prior to experiment the MOF was degassed under dynamic vacuum (30 mTorr) at 80 ◦C overnight. Adsorption isotherm was measured in a range of 10-5 < P/P0 < 0.995. Pore volume-size distribution was calculated using standard regularization procedure with kernel functions, calculated using NLDFT for silica cylindrical pores. Despite on obvious model restrictions, the calculated isotherm fitted well the experimental one, and the characteristic sizes from pore volume-size distributions correlate with the sizes from X-ray diffraction data. The hydrogen sorption isotherms were measured on BELSORP-max instrument using high-purity gas (99.9999%)\nin the range 0.0–1.0 bar at 77 K (liq. N2 bath) and 87 K (liq. Ar bath). Enthalpies of H2 adsorption were calculated using a variant of the Clausius–Clapeyron equation: ln(P1/P2) = DHads(T2 - T1)/(RT1T2), where Pn - pressure for isotherm n, Tn - temperature for isotherm n, R = 8.3145 J/(mol K). Pressure as a function of the amount adsorbed was determined using the Langmuir–Freundlich fit for each isotherm (see ESI† for details).11\n\n## X-Ray Crystallography\n\nSingle-crystal XRD data collections of 1–4 were performed by using an automated four circle Bruker–Nonius X8Apex CCD\ndiffractometer with Mo-Ka radiation (l = 0.71073 A˚ ). An absorbtion correction was applied based on the intensities of equivalent reflections with the use of the SADABS 12 program.')),
#  GraphDocument(nodes=[Node(id='Shelx-97', type='Mof'), Node(id='2,6-Naphtalenedicarboxylate', type='Linker'), Node(id='Urotropine', type='Linker'), Node(id='Benzene', type='Linker'), Node(id='Ferrocene', type='Linker'), Node(id='Dmf', type='Linker'), Node(id='Guest Water Molecules', type='Linker'), Node(id='1', type='Mof'), Node(id='2', type='Mof'), Node(id='4', type='Mof')], relationships=[Relationship(source=Node(id='1', type='Mof'), target=Node(id='Shelx-97', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='1', type='Mof'), target=Node(id='2,6-Naphtalenedicarboxylate', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='1', type='Mof'), target=Node(id='Urotropine', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='1', type='Mof'), target=Node(id='Benzene', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='1', type='Mof'), target=Node(id='Ferrocene', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='1', type='Mof'), target=Node(id='Dmf', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='1', type='Mof'), target=Node(id='Guest Water Molecules', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='2', type='Mof'), target=Node(id='1', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='4', type='Mof'), target=Node(id='1', type='Mof'), type='HAS_BOND')], source=Document(page_content='The structures were solved by direct method and refined on F2 by full-matrix least-squares method in the anisotropic approximation (for non-hydrogen atoms) using SHELX-97 program package.13 Positions of the hydrogen atoms of 2,6-naphtalenedicarboxylate, and urotropine ligands, guest benzene, ferrocene and DMF\nmolecules were calculated geometrically and refined by the rigid model. The hydrogen atoms of disordered guest water molecules in 1 were not located. In the case of 2 and 4 a racemic merohedral twinning was found with the twinning law of {-1, 0, 0; 0, -1, 0; 0, 0, -1} with relative component weights of 0.528(8)/0.472(8) for 2, and 0.512(7)/0.488(7) for 4. X-ray data collections have been performed for several crystals of 1. The data given for 1 in the paper are the best we could achieve. Apparently, lower quality of X-ray data of 1 is due to non-ideal crystal quality and disordering in guest subsystem. A summary of the crystallographic data and structural determination for 1–4 is provided in Table 1. Selected bond length and angles are listed in Tables S1–S4 (see ESI†).'))]

# %% [markdown]
# ### Changing Langchain's source code to allow for optional "additional context" prompt

# %%
context = ''' 
### **Node Types:**
- **MOF (Metal-Organic Framework):** Refers to compounds consisting of metal ions or clusters coordinated to organic ligands.
- **Bond:** Represents a connection between two atoms within a MOF.
- **Atom:** The basic unit of a chemical element in a MOF.
- **Metal:** A chemical element forming positive ions and involved in the MOF's structure.
- **Linker:** An organic molecule connecting metal ions or clusters in a MOF.

### **Relationship Types:**
- **Has_Bond:** Links an "Atom" to another "Atom" via a bond within a MOF.
- **Has_Atom:** Indicates that a "MOF" contains a specific "Atom".
- **Has_Linker:** Indicates that a "MOF" contains a specific "Linker".

### **Important Guidelines:**
1. **Scientific Context:** Interpret terms within the context of chemistry. For example, "Atom" should refer to elements within a MOF, not other uses of the word.
2. **Disambiguation:** If a term could be ambiguous, prefer the scientific interpretation. Ignore non-scientific entities or terms unless directly relevant to MOFs.
3. **Entity Consistency:** Ensure consistent naming for entities. For example, always use the full name of a MOF or a chemical element even if it appears in a shortened form in the text.
4. **Domain-Specific Instructions:** Use technical jargon or abbreviations only within the context of chemistry, and classify them correctly.
5. **Filtering Non-Relevant Content:** Ignore or deprioritize non-scientific text or sections irrelevant to the chemistry-specific nodes and relationships.
6. **Known Misinterpretations:** Do not classify journal names, like "Dalton Transactions," as a scientific entity like "MOF."

### **Examples of Correct Classifications:**
- "The MOF Zn-BTC has a bond between Zinc (Metal) and Benzene Tricarboxylate (Linker)."
  - `{"head": "Zn-BTC", "head_type": "MOF", "relation": "Has_Bond", "tail": "Zinc", "tail_type": "Metal"}`
  - `{"head": "Zn-BTC", "head_type": "MOF", "relation": "Has_Linker", "tail": "Benzene Tricarboxylate", "tail_type": "Linker"}`

### **Incorrect Classifications to Avoid:**
- "Dalton Transactions is a journal related to MOFs."
  - **Incorrect:** `{"head": "Dalton Transactions", "head_type": "MOF", "relation": "Has_Linker", "tail": "MOFs", "tail_type": "Linker"}` 
  - **Correct Approach:** Do not classify "Dalton Transactions" as a "MOF" or any other node type.
'''

# %%
from custom_llm import LLMGraphTransformer as CustomLLMGraphTransformer
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(temperature=0, model_name="gpt-4o-mini")
llm_transformer = CustomLLMGraphTransformer(
  llm=llm, 
  context = context,
  allowed_nodes=["MOF", "Bond", "Atom", "Metal", "Linker"],
  allowed_relationships=["Has_Bond", "Has_Atom", "Has_Linker"],
)

# %%
from typing import List
from langchain_community.graphs.graph_document import GraphDocument
from langchain_core.documents import Document
def process_document(doc: Document) -> List[GraphDocument]:
    return llm_transformer.convert_to_graph_documents([doc])

# %%
# Process each chunk using the process_text function
custom_graph_documents = []
for chunk in chunks:
    custom_graph_document = process_document(chunk)
    custom_graph_documents.extend(custom_graph_document)

# Print or handle the processed graph_documents as needed
print(f"Processed {len(custom_graph_documents)} GraphDocuments.")
# Out:
# Processed 20 GraphDocuments.

# %%
custom_graph_documents
# Out:
# [GraphDocument(nodes=[Node(id='Dalton Transactions', type='Mof')], relationships=[], source=Document(page_content='This article is published as part of the *Dalton Transactions* **themed issue entitled:** \n\n# New Talent Asia\n\nHighlighting the excellent work being carried out by younger members of the inorganic academic community in Asia Guest Editor Masahiro Yamashita Tohoku University, Japan Published in issue 10, 2011 of *Dalton Transactions*\n\n![0_image_0.png](0_image_0.png)\n\nImage reproduced with permission of Kenneth Kam-Wing Lo Articles in the issue include: PERSPECTIVES: Pyrazolin-4-ylidenes: a new class of intriguing ligands Yuan Han and Han Vinh Huynh, *Dalton Trans*., 2011, DOI: 10.1039/C0DT01037E Solvent induced molecular magnetic changes observed in single-crystal-to-single-crystal transformation Zheng-Ming Hao and Xian-Ming Zhang, *Dalton Trans*., 2011, DOI: 10.1039/C0DT00979B, ARTICLES: \nNegative thermal expansion emerging upon structural phase transition in ZrV2O7 and HfV2O7 Yasuhisa Yamamura, Aruto Horikoshi, Syuma Yasuzuka, Hideki Saitoh and Kazuya Saito Dalton Trans., 2011, DOI: 10.1039/C0DT01087A \nPreparation of surface molecularly imprinted Ru-complex catalysts for asymmetric transfer hydrogenation in water media Zhihuan Weng, Satoshi Muratsugu, Nozomu Ishiguro, Shin-ichi Ohkoshi and Mizuki Tada Dalton Trans., 2011, DOI: 10.1039/C0DT00950D \nVisit the *Dalton Transactions* website for more cutting-edge inorganic and organometallic research www.rsc.org/dalton\n\n# Microporous Sensor: Gas Sorption, Guest Exchange And Guest-Dependant Luminescence Of Metal–Organic Framework†')),
#  GraphDocument(nodes=[Node(id='Zn(Ii)-Containing Metal–Organic Framework (Mof) [Zn4(Dmf)(Ur)2(Ndc)4]', type='Mof'), Node(id='Ndc2- = 2,6-Naphtalenedicarboxylate', type='Linker'), Node(id='Ur = Urotropin', type='Linker'), Node(id='Dmf = N,N¢-Dimethylformamide', type='Linker')], relationships=[Relationship(source=Node(id='Zn(Ii)-Containing Metal–Organic Framework (Mof) [Zn4(Dmf)(Ur)2(Ndc)4]', type='Mof'), target=Node(id='Ndc2- = 2,6-Naphtalenedicarboxylate', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn(Ii)-Containing Metal–Organic Framework (Mof) [Zn4(Dmf)(Ur)2(Ndc)4]', type='Mof'), target=Node(id='Ur = Urotropin', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn(Ii)-Containing Metal–Organic Framework (Mof) [Zn4(Dmf)(Ur)2(Ndc)4]', type='Mof'), target=Node(id='Dmf = N,N¢-Dimethylformamide', type='Linker'), type='HAS_LINKER')], source=Document(page_content='Sergey A. Sapchenko,a Denis G. Samsonenko,*a,b Danil N. Dybtsev,a,c Maxim S. Melgunovd and Vladimir P. Fedina,b Received 12th August 2010, Accepted 14th October 2010 DOI: 10.1039/c0dt00999g Zn(II)-containing metal–organic framework (MOF) [Zn4(dmf)(ur)2(ndc)4] (ndc2- =\n2,6-naphtalenedicarboxylate, ur = urotropin, dmf = N,N¢-dimethylformamide) was synthesized and characterized by X-ray crystallography and gas sorption analysis. Host MOF retains its crystallinity after guest removal and exchange. Single-crystal to single-crystal formation of different host–guest systems with benzene and ferrocene was investigated. Interesting guest-depended luminescence properties of the porous host framework were observed.\n\n## Introduction')),
#  GraphDocument(nodes=[Node(id='Metal–Organic Coordination Polymers', type='Mof'), Node(id='Metal Ions', type='Atom'), Node(id='Organic Bridging Ligands', type='Linker'), Node(id='Metal Coordination Complexes', type='Mof'), Node(id='Extended Metal–Organic Framework', type='Mof'), Node(id='Novel Compounds', type='Mof'), Node(id='Porous Metal–Organic Frameworks', type='Mof'), Node(id='Porous Coordination Polymers', type='Mof'), Node(id='Host–Guest Complexes', type='Mof')], relationships=[Relationship(source=Node(id='Metal–Organic Coordination Polymers', type='Mof'), target=Node(id='Metal Ions', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Metal–Organic Coordination Polymers', type='Mof'), target=Node(id='Organic Bridging Ligands', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Metal Coordination Complexes', type='Mof'), target=Node(id='Extended Metal–Organic Framework', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Extended Metal–Organic Framework', type='Mof'), target=Node(id='Novel Compounds', type='Mof'), type='HAS_BOND')], source=Document(page_content='Metal–organic coordination polymers constructed from metal ions and organic bridging ligands have attracted considerable attention in recent years.1 The wide variety of organic ligands and practically infinite number of ways to unite metal coordination complexes into extended metal–organic framework lead to a vast number of novel compounds with unique sorption, catalytic activity, luminescence, magnetism.2,3 While gas sorption or catalytic activity of metal–organic frameworks mainly depends on the structure, some other properties, *e.g.* luminescence, depend also on the guest composition, which could be directly applied for chemical sensing. Therefore the synthesis of porous metal–organic frameworks, which are capable of switching their functional characteristics upon guest-related transitions, is an important but challenging task. Other than luminescence itself, such sensor materials should feature at least two essential properties. Firstly, the size of porous channels must be sufficient for accommodation of functional guest species. Secondly, the metal–organic framework should be robust enough to maintain its porosity during the guest removal or exchange. Only several examples of porous coordination polymers with luminescence-based sensing of various guest molecules have been reported to date,4 therefore this highly promising area mainly remains underdeveloped. A\nparticularly important issue here is an unambiguous structural characterization of such host–guest complexes because it allows detailed investigation of interactions between guest molecule and porous framework as well as elucidates the sensing mechanism.')),
#  GraphDocument(nodes=[Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·5Dmf·H2O (1)', type='Mof')], relationships=[], source=Document(page_content="Single-crystal X-ray diffraction technique is often limited here, because of guest disorder problem or fragility of metal-organic single crystals during the guest exchange.5 In this work we describe the synthesis and characterization of a novel porous metal–organic coordination polymer\n[Zn4(dmf)(ur)2(ndc)4]·5DMF·H2O (1), which meets the abovementioned requirements for potential sensor applications. The solvent molecules can be removed from this MOF without loss of the sample's crystallinity. The resulting permanently porous framework demonstrates a reversible gas sorption as well as an uptake of various guests. The corresponding guest-free and guest-exchanged samples were characterized by a single-crystal X-ray diffraction analysis. Most interestingly, the luminescent properties of open framework [Zn4(dmf)(ur)2(ndc)4] are highly depended on the guest molecules, accommodated in the pores. The benzene molecules enhance the framework luminescence, while ferrocene effectively quenches it. Such pronounced guestdepended response could be applied for sensing of organic or organometallic molecules, many of which are very dangerous both to Nature and to human health.\n\n## Results And Discussion\n\nCompound 1 was obtained by heating a mixture of Zn(NO3)2·6H2O, 2,6-naphtalenedicarboxylic acid (H2ndc) and urotropin (ur) in DMF at 100 ◦C for 10 h. Compound 1 crystallizes in the monoclinic system with the space group P21/n. Asymmetric unit of 1 comprises four crystallographically independent zinc atoms forming two different binuclear carboxylate complexes as secondary building units (Fig. 1). In the first building unit (type A) the tetragonal-pyramidal Zn(1) and Zn(2) centers are similar.")),
#  GraphDocument(nodes=[Node(id='Zn2(Coo)4', type='Metal'), Node(id='Ndc2-', type='Linker'), Node(id='Urotropin', type='Linker'), Node(id='Zn(3)', type='Metal'), Node(id='Zn(4)', type='Metal'), Node(id='Dmf', type='Linker'), Node(id='O Atoms', type='Atom'), Node(id='N Atom', type='Atom')], relationships=[Relationship(source=Node(id='Zn2(Coo)4', type='Metal'), target=Node(id='Ndc2-', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn2(Coo)4', type='Metal'), target=Node(id='Urotropin', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn(3)', type='Metal'), target=Node(id='Ndc2-', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn(3)', type='Metal'), target=Node(id='Urotropin', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn(4)', type='Metal'), target=Node(id='Ndc2-', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn(4)', type='Metal'), target=Node(id='Dmf', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='Zn(3)', type='Metal'), target=Node(id='O Atoms', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Zn(3)', type='Metal'), target=Node(id='N Atom', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Zn(4)', type='Metal'), target=Node(id='O Atoms', type='Atom'), type='HAS_ATOM'), Relationship(source=Node(id='Zn(4)', type='Metal'), target=Node(id='N Atom', type='Atom'), type='HAS_ATOM')], source=Document(page_content='Each metal cation is coordinated by four O atoms of four ndc2- and one N atom of urotropin, such as these cations are interconnected via four bridging bidentate m2-RCOO-O,O¢ groups. This binuclear carboxylate complex {Zn2(COO)4}, known as "paddle-wheel",\nis very typical and common in metal carboxylate coordination structures. The Zn–O (2.006(5)–2.069(6) A˚ ) and Zn–N (2.065(6), 2.067(6) A˚ ) bond lengths found fall within the common values for Zn(II) complexes with coordination number 5. The structure of the second carboxylate secondary building unit (type B), to our best\n\n![2_image_0.png](2_image_0.png)\n\nknowledge, has never been described before and unprecedented in coordination frameworks. Contrary to the binuclear complex A, the coordination environments of Zn(3) and Zn(4) cations in B are different (Fig. 1). The distorted tetrahedral Zn(3) center is coordinated by three O atoms of three ndc2- ligands and one N atom of urotropin. The Zn(3)–O (1,899(9)–1,962(7) A˚ ) and Zn(3)–N(12) (2.111(7) A˚ ) bond lengths found fall within the common values for tetrahedral Zn(II) complexes. The distorted octahedral geometry of Zn(4) cation is composed of five O atoms of two monodentate ndc2-, one chelating bidentate ndc2- ligands and one coordinated dmf molecule, as well as one N atom of urotropin ligand. The Zn(4)–N(22) bond length is 2.143(7) A˚ .')),
#  GraphDocument(nodes=[Node(id='Zn(4)', type='Metal'), Node(id='Ndc2-', type='Linker'), Node(id='Bidentate Ndc2-', type='Linker'), Node(id='Zn(3)', type='Metal'), Node(id='M2-Rcoo-O,O¢', type='Linker'), Node(id='{Zn2(Dmf)(Coo)4}', type='Mof'), Node(id='Ndc2-', type='Linker'), Node(id='Urotropin', type='Linker'), Node(id='Type A', type='Mof'), Node(id='Type B', type='Mof')], relationships=[Relationship(source=Node(id='Zn(4)', type='Metal'), target=Node(id='Ndc2-', type='Linker'), type='HAS_BOND'), Relationship(source=Node(id='Zn(4)', type='Metal'), target=Node(id='Bidentate Ndc2-', type='Linker'), type='HAS_BOND'), Relationship(source=Node(id='Zn(3)', type='Metal'), target=Node(id='M2-Rcoo-O,O¢', type='Linker'), type='HAS_BOND'), Relationship(source=Node(id='Zn(4)', type='Metal'), target=Node(id='{Zn2(Dmf)(Coo)4}', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Ndc2-', type='Linker'), target=Node(id='Type A', type='Mof'), type='HAS_LINKER'), Relationship(source=Node(id='Ndc2-', type='Linker'), target=Node(id='Type B', type='Mof'), type='HAS_LINKER'), Relationship(source=Node(id='Urotropin', type='Linker'), target=Node(id='Type A', type='Mof'), type='HAS_LINKER'), Relationship(source=Node(id='Urotropin', type='Linker'), target=Node(id='Type B', type='Mof'), type='HAS_LINKER')], source=Document(page_content='There are two type of Zn(4)–O distances. The first one includes two bonds with bridging ndc2- ligands (1.982(7), 1.997(6) A˚ )\nand one of two bonds with bidentate ndc2- ligand (2.161(16)\nA˚ ). The residual bond with bidentate ndc2- ligand and bond with dmf molecule form the second type. Thereby, coordination number of Zn(4) atom can be assigned as 4 + 2. In the type B\nbuilding unit two metal cations Zn(3) and Zn(4) are interlinked via two bridging m2-RCOO-O,O¢ groups, so the overall formula of the coordination complex is {Zn2(dmf)(COO)4}. The metal–\nligand distances in both carboxylate binuclear complexes lie within typical corresponding ranges with some acceptable deviations, indicating apparent distortion.\n\nIn the structure 1 the organic ligands act as ditopic connectors between the binuclear secondary building units. Therefore, both binuclear complexes A and B could be simplified as six-connected nodes, each with distorted 4 + 2 octahedral geometry of four linear ndc2- and two angular urotropin linkers. The main difference is that urotropins are located in *trans*-positions in type A but in cis-positions in the type B node (Fig. 1). The ndc2- bridges connect nodes A and A, B and B, as well as A and B. At the same time urotropin ligands link only nodes A and B. Each type A node is connected through ndc2- to two nodes A and two nodes B\nand through urotropin to two nodes B. Similarly, each B node is connected through ndc2- to two nodes A and two B and through urotropin to two nodes A. The overall three-dimensional (3D)\ntopology of the binodal 6-connected net in the metal–organic framework 1 is very complicated (Fig. S1†), one may refer to its point symbol (3244.68.8)(3.44.53.66.8).')),
#  GraphDocument(nodes=[Node(id='1', type='Mof'), Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof')], relationships=[], source=Document(page_content='The interstitial space between inorganic carboxylate complexes and organic ligands in as-synthesized 1 is occupied by solvent guest molecules. The single-crystal X-ray diffraction analysis revealed five DMF and one H2O molecules per asymmetric unit of 1. The formula [Zn4(dmf)(ur)2(ndc)4]·5DMF·H2O was independently confirmed by elemental and thermogravimetrical\n(TG) analyses. The phase purity of 1 was also proved by powder X-ray diffraction method (See SI for the details). In particular, the TG analysis on the as-synthesized 1 indicated a gradual weight loss of 21% in the temperature range 25–300 ◦C, which is consistent with evacuation of one H2O and 5 DMF molecules. The following decrease of mass can be associated with the destruction of the metal–organic framework (Fig. S2). The guest molecules occupy distorted hexagonal channels with characteristic dimensions 9.5\n¥ 11 A˚ 2, running along a axis of 3D framework (Fig. 2). A space within channels is occupied by DMF and disordered H2O guest molecules, which form a weak H-bonding with CH or CH2 groups of ndc2- or urotropin ligands respectively, as well as with each\n\n![3_image_1.png](3_image_1.png)')),
#  GraphDocument(nodes=[Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), Node(id='Compound 1', type='Mof'), Node(id='Compound 2', type='Mof'), Node(id='P21/N', type='Bond'), Node(id='Cc', type='Bond')], relationships=[Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), target=Node(id='Compound 2', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Compound 1', type='Mof'), target=Node(id='P21/N', type='Bond'), type='HAS_BOND'), Relationship(source=Node(id='Compound 2', type='Mof'), target=Node(id='Cc', type='Bond'), type='HAS_BOND')], source=Document(page_content='To prepare guest-free framework [Zn4(dmf)(ur)2(ndc)4] (2) the DMF molecules was exchanged with readily volatile CH2Cl2 solvent, followed by slight heating in the dynamic vacuum. A structure of guest-free compound 2 is generally similar to 1, but there are some distinct differences. Whereas the compound 1 crystallizes in *P21/n* space group, compound 2 has slightly higher Cc symmetry. Such difference does not affect significantly Zn– O and Zn–N interatomic distances. The channels running along c axis in 2 adopt more symmetric shape than in 1 and have characteristic dimensions 10.5 ¥ 10.5 A˚ (Fig. 3). The free solvent accessible volume in 2, derived from PLATON 6 routine analysis\n(filling of the cavities with probe spheres of radius 1.2 A˚ ) was found to be 43%. Interestingly, framework 2 is not centrosymmetric\n(sp. group Cc has no inversion center) that leads to racemic merohedral twinning of the crystals 2 contrary to 1. Attempts to apply centrosymmetric space group C2/c during the refinement of 2 leads to disorder of coordinated dmf molecules over two symmetrically related positions. In case of non centrosymmetric group Cc, the disordering is not observed.\n\nThe high stability of the guest-free metal–organic framework was further confirmed by N2 sorption isotherm at 77 K for 2\n(Fig. 4), which shows type I behavior with small hysteresis and\n\n![3_image_0.png](3_image_0.png)\n\n![3_image_2.png](3_image_2.png)')),
#  GraphDocument(nodes=[Node(id='Brunauer–Emmett–Teller', type='Mof'), Node(id='H2', type='Atom'), Node(id='Liquid H2', type='Atom'), Node(id='Hydrogen', type='Atom'), Node(id='Benzene', type='Atom'), Node(id='Inclusion Compound [Zn4(Dmf)(Ur)2(Ndc)4]·6C6H6', type='Mof'), Node(id='Framework Structure Of Benzene Adduct 3', type='Mof')], relationships=[Relationship(source=Node(id='Inclusion Compound [Zn4(Dmf)(Ur)2(Ndc)4]·6C6H6', type='Mof'), target=Node(id='Framework Structure Of Benzene Adduct 3', type='Mof'), type='HAS_BOND')], source=Document(page_content='thus ensuring permanent microporosity of the bulk sample. The formally calculated Brunauer–Emmett–Teller (BET) surface area is 820 m2 g-1. Channels volume-size distribution diagram (Fig. S3†)\nshows the only intense peak at 0.9 nm and agrees quantitatively with the result of X-ray analysis. The volume of these pores was calculated to be 0.2 cm3 g-1. The maximum H2 uptake for 2 at 1 atm and 77 K is 0.92 wt.% H2 (Fig. 5). Knowing pore volume, one can estimate the density of H2 in pores as 0.04 g cm-3. For comparison, density of liquid H2 at 14 K is 0.07 g cm-3. The storage density of hydrogen in the bulk sample at 1 bar is 0.009 g cm-3, which is equivalent to the density of H2 at 2.7 MPa (estimated according\n\n![4_image_0.png](4_image_0.png)\n\nto ideal gas equation) at 77 K. Additional hydrogen isotherm was measured at 87 K to determine enthalpy of adsorption derived from the Clausius–Clapeyron equation (see Fig. S4 and S5 in ESI† for details). In the interval of 0.1–1.0 wt. % of adsorbed H2, value of D*Hads* lies in the range 4.7–5.2 kJ mol-1, which is typical to other zinc–organic frameworks.2a Microporous framework 2 can form different host–guest complexes with various species ranging from diatomic molecules to organometallics. Immersing single crystals of 2 in liquid benzene at room temperature for 16 h leads to single crystals of inclusion compound [Zn4(dmf)(ur)2(ndc)4]·6C6H6 (3). The framework structure of benzene adduct 3 is practically identical to one in 1. In both cases, a presence of guest molecules distorts the framework symmetry and space group is changed back to P21/n. A space within the channels is occupied by benzene molecules (Fig. 6).')),
#  GraphDocument(nodes=[Node(id='Zn(4)', type='Atom'), Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·4Fe(C5H5)2 (4)', type='Mof'), Node(id='3', type='Mof'), Node(id='1', type='Mof'), Node(id='2', type='Mof')], relationships=[Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·4Fe(C5H5)2 (4)', type='Mof'), target=Node(id='3', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·4Fe(C5H5)2 (4)', type='Mof'), target=Node(id='1', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]·4Fe(C5H5)2 (4)', type='Mof'), target=Node(id='2', type='Mof'), type='HAS_BOND')], source=Document(page_content='There are no strong contacts between guest benzene molecules except for specific C–H ◊◊◊p interactions (Fig. S6†), which are common in such aryl molecules packing.7 We also found some weak H-bonds between CH group of benzene and carboxyl group of ndc2- ligand. The host–guest adduct with ferrocene was prepared by heating a mixture of single crystals of 2 and solid ferrocene in an evacuated sealed glass tube at 100 ◦C for 10 h. After slow cooling to room temperature, yellow crystals of\n[Zn4(dmf)(ur)2(ndc)4]·4Fe(C5H5)2 (4) were separated from excess of the ferrocene. Noteworthy, the corresponding ferrocene adduct cannot be obtained by a reaction of 2 with ferrocene solution in cyclohexane. As identified from the single-crystal X-ray diffraction data, the ferrocene-imbued framework of host–guest system 4 has less distorted monoclinic Cc space group symmetry compared to that in 3 (Fig. 7). The most significant difference in 4 is that the all three ndc2- ligands are coordinated to Zn(4) atom on monodentate manner, whereas in 1–3 one ndc2- ligand is always bidentate. As a result, Zn(4) in structure 4 has distorted trigonal bipyramidal coordination environment in contrast to distorted octahedral one in 1–3 (Fig. S7†). A space within the channels is occupied by ferrocene molecules of four crystallographically independent types. Interestingly, one of them is disordered over two positions with the site occupancy factors being 0.32 and 0.68 (Fig. S8†). Except for van-der-Waals contacts, we could not identify any specific interactions between ferrocene molecules and the framework, as well as between guest molecules. We note here, that the framework stability and phase purity of guest-exchange compounds 3 and 4 were independently confirmed by X-ray powder diffraction method (Fig. S9†).\n\nThe solid-state photoluminescence properties of complexes 1–4 were investigated at room temperature (Fig. 8, Fig. S10†).')),
#  GraphDocument(nodes=[Node(id='Ferrocene', type='Atom'), Node(id='Ndc2-', type='Atom'), Node(id='Fecp2', type='Atom'), Node(id='Framework', type='Mof')], relationships=[Relationship(source=Node(id='Ndc2-', type='Atom'), target=Node(id='Ferrocene', type='Atom'), type='HAS_BOND'), Relationship(source=Node(id='Ferrocene', type='Atom'), target=Node(id='Fecp2', type='Atom'), type='HAS_BOND'), Relationship(source=Node(id='Fecp2', type='Atom'), target=Node(id='Framework', type='Mof'), type='HAS_BOND')], source=Document(page_content='Their emissions spectra were collected from 380 nm to 600 nm with excitation wavelength at l = 370 nm. The positions of maxima of the photoluminescence spectra for the materials 1–3 are the identical. Some deviations in the luminescence intensities for these materials could be attributed to the method errors. All compounds 1–3 exhibit strong blue emission with broad maximum at l = 430 nm which can be assigned to naphtalenedicarboxylate (ndc2-) intraligand emission p–p*. However, the presence of ferrocene in the host–guest compound 4 essentially quenches the photoluminescence of the framework. In fact, the ferrocene molecule and its derivatives have been widely used as a luminescence quenchers,8 particularly, because of their high stability under visible irradiation and capacity to inhibit the lowest energy excited states (generally, the triplet state).9 Such photoluminescence quenching led to numerous applications in the areas of analytical chemistry, molecular organized systems and biology.10 The excitation energy is transferred to the ferrocene FeCp2, followed by the thermal relaxation of the excited FeCp2* state. There are two possible luminescence quenching mechanisms, known as energy transfer and electron transfer.9 The later is unlikely, because it should involve electron transfer from the ferrocene to exited anionic ligand, forming intermediate radical species ndc3-∑, which should be very unstable. The energy transfer mechanism requires the luminescence radiation energy to be higher, than the energy of the first exited state of ferrocene FeCp2*, which is 21800 cm-1. As mentioned above, the emitted radiation wavelength of p–p* transitions in ndc2- has maximum at l = 430 nm (or 23250 cm-1), which is just enough to promote the ferrocene excitation and effectively absorb the framework photoluminescence. Therefore, we believe that observed quenching of the metal–organic framework luminescence by the ferrocene follows the energy transfer mechanisms. The unique')),
#  GraphDocument(nodes=[Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]', type='Mof'), Node(id='Microporous Metal–Organic Material', type='Mof')], relationships=[Relationship(source=Node(id='[Zn4(Dmf)(Ur)2(Ndc)4]', type='Mof'), target=Node(id='Microporous Metal–Organic Material', type='Mof'), type='HAS_BOND')], source=Document(page_content='combination of the pronounced guest-dependant photoluminescence, great framework stability and potent sorption capability of microporous metal–organic material [Zn4(dmf)(ur)2(ndc)4] makes is very strong candidate for practical sensing applications for aromatic or other compounds. More experiments are currently under way in order to investigate the relations between host–guest interactions and luminescence properties of such supramolecular compounds.')),
#  GraphDocument(nodes=[Node(id='Zn(Ii) Metal–Organic Framework', type='Mof'), Node(id='Guest Molecules', type='Atom'), Node(id='Nitrogen', type='Atom'), Node(id='Hydrogen', type='Atom')], relationships=[], source=Document(page_content='## Conclusions\n\nA novel microporous Zn(II) metal–organic framework with permanent porosity has been synthesized and structurally characterized. It is shown that as-synthesized form of this MOF-material retains its single crystallinity after guest molecules removal or exchange. The permanent porosity was further confirmed by nitrogen and hydrogen sorption data. Additionally, the pronounced guest-depended photoluminescence properties have been demonstrated, which open great possibilities to use this material for practical sensing applications.\n\n## Experimental General Remarks\n\nAll chemicals purchased were of reagent grade and were used as received without further purification. Methylene chloride was purified according to standard procedure. FTIR spectra (KBr pellets) were recorded in the range of 4000–400 cm-1 on a Scimitar FTS 2000 Fourier-transform infrared spectrometer. Powder X-ray diffraction (PXRD) data were collected with Cu-Ka radiation on a Philips PW 1830 instrument equipped with a PW 1820 vertical Bragg–Brentano powder goniometer and a PW 1710 control unit.\n\n![5_image_0.png](5_image_0.png)\n\n![6_image_0.png](6_image_0.png)\n\nThermogravimetric analysis (TGA) was carried out at a ramp rate of 10 ◦C min-1 in a helium atmosphere with a NETZSCH\nTG 209 F1 instrument. Elemental analyses on C, H, and N\nwere performed on a Euro EA 3000 CHN Elemental Analyzer.\n\nFluorescence emission spectra were collected on a Varian Cary Eclipse spectrofluorimeter.\n\n## Synthesis')),
#  GraphDocument(nodes=[Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), Node(id='Zn(No3)2·6H2O', type='Mof'), Node(id='2,6-Naphtalenedicarboxylic Acid', type='Mof'), Node(id='Urotropine', type='Mof'), Node(id='Dmf', type='Mof'), Node(id='Colorless Crystals Of 1', type='Mof'), Node(id='Diethylether', type='Mof')], relationships=[Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), target=Node(id='Dmf', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Zn(No3)2·6H2O', type='Mof'), target=Node(id='2,6-Naphtalenedicarboxylic Acid', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Zn(No3)2·6H2O', type='Mof'), target=Node(id='Urotropine', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Colorless Crystals Of 1', type='Mof'), target=Node(id='Dmf', type='Mof'), type='HAS_BOND'), Relationship(source=Node(id='Colorless Crystals Of 1', type='Mof'), target=Node(id='Diethylether', type='Mof'), type='HAS_BOND')], source=Document(page_content='[Zn4(dmf)(ur)2(ndc)4]·5DMF·**H2O (1).** A mixture of Zn(NO3)2·6H2O (0.300 g, 1.00 mmol), 2,6-naphtalenedicarboxylic acid (0.216 g, 1.00 mmol), and urotropine (0.070 g, 0.50 mmol)\nin DMF (25 mL) was heated at 100 ◦C for 10 h in teflon-lined capped container under autogenous pressure. After slow cooling to room temperature, colorless crystals of 1 were separated by filtration, washed with DMF, and then diethylether and dried on air. Yield 0.434 g (28%). Anal: Calc. for C78H92N14O23Zn4 (%) C\n50.5; H 5.0; N 10.6. Found (%): C 49.9; H 5.2; N 10.6. IR (KBr, cm-1): 3435 (w), 3060 (w), 2928 (w), 1666 (s), 1616 (m), 1585 (m),\n1496 (w), 1408 (s), 1356 (m), 1251 (w), 1227 (w), 1196 (w), 1096 (w), 1027 (m), 993 (m), 922 (w), 836 (w), 784 (s), 730 (w), 660 (w),\n588 (w), 481 (m). TGA data: calc. weight loss for 5DMF + H2O:\n21%; found: 21%.\n\n[Zn4(dmf)(ur)2(ndc)4] (2). The crystals of 1 (0.100 g, 0.056 mmol) were immersed into dried CH2Cl2 (15 mL) for 72 h,')),
#  GraphDocument(nodes=[], relationships=[], source=Document(page_content='| Table 1                                  | Crystal data and structure refinement for 1–4   |                                          |                    |                    |\n|------------------------------------------|-------------------------------------------------|------------------------------------------|--------------------|--------------------|\n| Compounds                                | 1                                               | 2                                        | 3                  | 4                  |\n| Empirical formula                        | C78H92N14O23Zn4                                 | C63H55N9O17Zn4                           | C99H91N9O17Zn4     | C103H95N9O17Zn4Fe4 |\n| Formula weight                           | 1855.14                                         | 1471.64                                  | 1940.29            | 2215,76            |\n| T/K                                      | 150(2)                                          | 150(2)                                   | 150(2)             | 130(2)             |\n| Crystal system                           | Monoclinic                                      | Monoclinic                               | Monoclinic         | Monoclinic         |\n| Space group                              | P21/n                                           | Cc                                       | P21/n              | Cc                 |\n| a/A˚                                     | 12.3274(5)                                      | 24.8414(6)                               | 12.2527(2)         | 24.6659(7)         |\n| b/A˚                                     | 30.5413(19)                                     | 31.1031(8)                               | 31.2515(5)         | 31.3085(12)        |\n| c/A˚                                     | 24.7472(15)                                     | 12.3400(3)                               | 24.7184(4)         | 12.2751(5)         |')),
#  GraphDocument(nodes=[], relationships=[], source=Document(page_content='| b/◦                                      | 98.232(1)                                       | 97.318(1)                                | 97.023(1)          | 96.306(1)          |\n| Volume/A˚ 3                              | 9221.2(9)                                       | 9456.8(4)                                | 9394.0(3)          | 9422.1(6)          |\n| Z                                        | 4                                               | 4                                        | 4                  | 4                  |\n| Dcalc/g cm-3                             | 1.336                                           | 1.034                                    | 1.372              | 1.562              |\n| Absorbtion coefficient/mm-1              | 1.103                                           | 1.054                                    | 1.080              | 1.672              |\n| F(000)                                   | 3848                                            | 3008                                     | 4016               | 4544               |\n| Crystal size/mm                          | 0.32 ¥ 0.11 ¥ 0.07                              | 0.36 ¥ 0.16 ¥ 0.14                       | 0.20 ¥ 0.18 ¥ 0.12 | 0,09 ¥ 0,08 ¥ 0,06 |\n| q for data collection/◦                  | 1.79–26.39                                      | 2.11–30,54                               | 2.06–30.52         | 2.12–27.53         |\n| Limiting indices                         | -15 £ h £ 8, -38 £ k £ 38, -30 £ l £ 30         | -31 £ h £ 18, -40 £ k £ 40, -15 £ l £ 15 |                    |                    |\n| Reflns collected/unique                  | 57408/18509                                     | 61839/25216                              | 125023/28654       | 36506/17100        |\n| Rint                                     | 0.0555                                          | 0.0171                                   | 0.0279             | 0.0335             |')),
#  GraphDocument(nodes=[], relationships=[], source=Document(page_content='| Goodness-of-fit on F2                    | 1.104                                           | 1.097                                    | 1.037              | 1.023              |\n| Absolute structure parameter             | -                                               | 0.472(8)                                 | -                  | 0.488(7)           |\n| Final R indices [I > 2s(I)]              | R1 = 0.1079                                     | R1 = 0.0374                              | R1 = 0.0367        | R1 = 0.0349        |\n| wR2 = 0.2833                             | wR2 = 0.1271                                    | wR2 = 0.0879                             | wR2 = 0.0672       |                    |\n| R indices (all data)                     | R1 = 0.1451                                     | R1 = 0.0423                              | R1 = 0.0492        | R1 = 0.0482        |\n| wR2 = 0.2973                             | wR2 = 0.1311                                    | wR2 = 0.0916                             | wR2 = 0.0706       |                    |\n| Largest diff. peak and hole/e A˚ -3      | 1.704/-0.950                                    | 1.230/-0.406                             | 0.980/-0.795       | 0.811/-0.850       |\n| -35 £ h £ 31, -44 £ k £ 40, -16 £ l £ 17 | -17 £ h £ 17, -44 £ k £ 39, -35 £ l £ 32        |                                          |                    |                    |')),
#  GraphDocument(nodes=[Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), Node(id='C6H6', type='Linker'), Node(id='C99H91N9O17Zn4', type='Mof'), Node(id='C103H95N9O17Zn4Fe4', type='Mof'), Node(id='Ferrocene', type='Atom')], relationships=[Relationship(source=Node(id='Zn4(Dmf)(Ur)2(Ndc)4', type='Mof'), target=Node(id='C6H6', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='C99H91N9O17Zn4', type='Mof'), target=Node(id='C6H6', type='Linker'), type='HAS_LINKER'), Relationship(source=Node(id='C103H95N9O17Zn4Fe4', type='Mof'), target=Node(id='Ferrocene', type='Atom'), type='HAS_ATOM')], source=Document(page_content='![7_image_0.png](7_image_0.png)\n\nand then heated under dynamic vacuum at 65 ◦C for 24 h. Anal:\nCalc. for C63H55N9O17Zn4 (%): C 51.4; H 3.8; N 8.6. Found (%): C\n51,7; H 3,8; N 8,7.\n\n[Zn4(dmf)(ur)2(ndc)4]·6C6H6 **(3).** The crystals of 2 (0.100 g, 0.068 mmol) were immersed in benzene (10 ml) for 72 h. After that, colorless crystals of 3 was separated by filtration, and dried on air. Anal: Calc. for C99H91N9O17Zn4 (%): C 61.3; H 4.7; N 6.5.\n\nFound (%): C 60.9; H 4.4; N 6.7.\n\n[Zn4(dmf)(ur)2(ndc)4]·4Fe(C5H5)2 **(4).** A mixture of crystals of 2 (0.050 g, 0.034 mmol), and ferrocene (0.025 g, 0.136 mmol) was heated in evacuated sealed glass tube at 100 ◦C for 10 h. After slow cooling to room temperature, yellow crystals of 4 were separated from excess of ferrocene crystallized on the inner side wall of glass tube. Anal: Calc. for C103H95N9O17Zn4Fe4 (%): C 55.8; H 4.3; N\n5.7. Found (%): C 55.7; H 4.4; N 5.7.\n\n## Gas Sorption Measurements')),
#  GraphDocument(nodes=[Node(id='Dichloromethylene-Exchanged Sample 1', type='Mof')], relationships=[], source=Document(page_content='The dichloromethylene-exchanged sample 1 was activated in vacuum at 100 ◦C for 14 h. Nitrogen adsorption at 77 K was studied by means of Autosorb-6B-Kr (Quantachrome) instrument. Prior to experiment the MOF was degassed under dynamic vacuum (30 mTorr) at 80 ◦C overnight. Adsorption isotherm was measured in a range of 10-5 < P/P0 < 0.995. Pore volume-size distribution was calculated using standard regularization procedure with kernel functions, calculated using NLDFT for silica cylindrical pores. Despite on obvious model restrictions, the calculated isotherm fitted well the experimental one, and the characteristic sizes from pore volume-size distributions correlate with the sizes from X-ray diffraction data. The hydrogen sorption isotherms were measured on BELSORP-max instrument using high-purity gas (99.9999%)\nin the range 0.0–1.0 bar at 77 K (liq. N2 bath) and 87 K (liq. Ar bath). Enthalpies of H2 adsorption were calculated using a variant of the Clausius–Clapeyron equation: ln(P1/P2) = DHads(T2 - T1)/(RT1T2), where Pn - pressure for isotherm n, Tn - temperature for isotherm n, R = 8.3145 J/(mol K). Pressure as a function of the amount adsorbed was determined using the Langmuir–Freundlich fit for each isotherm (see ESI† for details).11\n\n## X-Ray Crystallography\n\nSingle-crystal XRD data collections of 1–4 were performed by using an automated four circle Bruker–Nonius X8Apex CCD\ndiffractometer with Mo-Ka radiation (l = 0.71073 A˚ ). An absorbtion correction was applied based on the intensities of equivalent reflections with the use of the SADABS 12 program.')),
#  GraphDocument(nodes=[], relationships=[], source=Document(page_content='The structures were solved by direct method and refined on F2 by full-matrix least-squares method in the anisotropic approximation (for non-hydrogen atoms) using SHELX-97 program package.13 Positions of the hydrogen atoms of 2,6-naphtalenedicarboxylate, and urotropine ligands, guest benzene, ferrocene and DMF\nmolecules were calculated geometrically and refined by the rigid model. The hydrogen atoms of disordered guest water molecules in 1 were not located. In the case of 2 and 4 a racemic merohedral twinning was found with the twinning law of {-1, 0, 0; 0, -1, 0; 0, 0, -1} with relative component weights of 0.528(8)/0.472(8) for 2, and 0.512(7)/0.488(7) for 4. X-ray data collections have been performed for several crystals of 1. The data given for 1 in the paper are the best we could achieve. Apparently, lower quality of X-ray data of 1 is due to non-ideal crystal quality and disordering in guest subsystem. A summary of the crystallographic data and structural determination for 1–4 is provided in Table 1. Selected bond length and angles are listed in Tables S1–S4 (see ESI†).'))]

# %%
allowed_nodes=["MOF", "Bond", "Atom", "Metal", "Linker"],
allowed_relationships=["Has_Bond", "Has_Atom", "Has_Linker"],

from custom_llm import create_unstructured_prompt
prompt = create_unstructured_prompt(
    node_labels=allowed_nodes,
    rel_types=allowed_relationships,
    additional_context=context
)
print(prompt)
# Out:
# input_variables=['"head"', 'input'] messages=[SystemMessage(content='You are a top-tier algorithm designed for extracting information in structured formats to build a knowledge graph. Your task is to identify the entities and relations requested with the user prompt from a given text. You must generate the output in a JSON format containing a list with JSON objects. Each object should have the keys: "head", "head_type", "relation", "tail", and "tail_type". The "head" key must contain the text of the extracted entity with one of the types from the provided list in the user prompt.\nThe "head_type" key must contain the type of the extracted head entity, which must be one of the types from ([\'MOF\', \'Bond\', \'Atom\', \'Metal\', \'Linker\'],).\nThe "relation" key must contain the type of relation between the "head" and the "tail", which must be one of the relations from ([\'Has_Bond\', \'Has_Atom\', \'Has_Linker\'],).\nThe "tail" key must represent the text of an extracted entity which is the tail of the relation, and the "tail_type" key must contain the type of the tail entity from ([\'MOF\', \'Bond\', \'Atom\', \'Metal\', \'Linker\'],).\nAttempt to extract as many entities and relations as you can. Maintain Entity Consistency: When extracting entities, it\'s vital to ensure consistency. If an entity, such as "John Doe", is mentioned multiple times in the text but is referred to by different names or pronouns (e.g., "Joe", "he"), always use the most complete identifier for that entity. The knowledge graph should be coherent and easily understandable, so maintaining consistency in entity references is crucial.\n \n### **Node Types:**\n- **MOF (Metal-Organic Framework):** Refers to compounds consisting of metal ions or clusters coordinated to organic ligands.\n- **Bond:** Represents a connection between two atoms within a MOF.\n- **Atom:** The basic unit of a chemical element in a MOF.\n- **Metal:** A chemical element forming positive ions and involved in the MOF\'s structure.\n- **Linker:** An organic molecule connecting metal ions or clusters in a MOF.\n\n### **Relationship Types:**\n- **Has_Bond:** Links an "Atom" to another "Atom" via a bond within a MOF.\n- **Has_Atom:** Indicates that a "MOF" contains a specific "Atom".\n- **Has_Linker:** Indicates that a "MOF" contains a specific "Linker".\n\n### **Important Guidelines:**\n1. **Scientific Context:** Interpret terms within the context of chemistry. For example, "Atom" should refer to elements within a MOF, not other uses of the word.\n2. **Disambiguation:** If a term could be ambiguous, prefer the scientific interpretation. Ignore non-scientific entities or terms unless directly relevant to MOFs.\n3. **Entity Consistency:** Ensure consistent naming for entities. For example, always use the full name of a MOF or a chemical element even if it appears in a shortened form in the text.\n4. **Domain-Specific Instructions:** Use technical jargon or abbreviations only within the context of chemistry, and classify them correctly.\n5. **Filtering Non-Relevant Content:** Ignore or deprioritize non-scientific text or sections irrelevant to the chemistry-specific nodes and relationships.\n6. **Known Misinterpretations:** Do not classify journal names, like "Dalton Transactions," as a scientific entity like "MOF."\n\n### **Examples of Correct Classifications:**\n- "The MOF Zn-BTC has a bond between Zinc (Metal) and Benzene Tricarboxylate (Linker)."\n  - `{"head": "Zn-BTC", "head_type": "MOF", "relation": "Has_Bond", "tail": "Zinc", "tail_type": "Metal"}`\n  - `{"head": "Zn-BTC", "head_type": "MOF", "relation": "Has_Linker", "tail": "Benzene Tricarboxylate", "tail_type": "Linker"}`\n\n### **Incorrect Classifications to Avoid:**\n- "Dalton Transactions is a journal related to MOFs."\n  - **Incorrect:** `{"head": "Dalton Transactions", "head_type": "MOF", "relation": "Has_Linker", "tail": "MOFs", "tail_type": "Linker"}` \n  - **Correct Approach:** Do not classify "Dalton Transactions" as a ...
